# %%
def IoU(ground_truth: list, prediction: list):
    from sympy import Interval
    from sympy.sets.sets import EmptySet

    if min(ground_truth) == max(ground_truth):
        ground_truth = [min(ground_truth) - 3, max(ground_truth) + 3]

    ground_truth_interval = Interval(min(ground_truth), max(ground_truth))
    prediction_interval = Interval(min(prediction), max(prediction))

    intersection = ground_truth_interval.intersection(prediction_interval)
    if isinstance(intersection, EmptySet) or not isinstance(intersection, Interval):
        return 0

    union = ground_truth_interval.union(prediction_interval)

    return float((intersection.end.evalf() - intersection.start.evalf()) / (union.end.evalf() - union.start.evalf()))

# %%
def mIoU(ground_truth: list, predictions: list):
    N = len(predictions)
    sIoU = sum([IoU(ground_truth, prediction) for prediction in predictions])
    return sIoU / N

# %%
root = '/content/drive/MyDrive/Colab_Notebooks/POLITO/Primer_anno/Machine_learning_and_deep_learning/Project/'
test_models_folder = 'Test_models/'
egovlp_annotations = 'egovlp_annotations/'
predictions_filename = 'juli_sample_200_nlq'
ground_truth_filename = 'nlq_val'
extension = 'json'

predictions_path = root + test_models_folder + predictions_filename + '.' + extension
ground_truth_path = root + egovlp_annotations + ground_truth_filename + '.' + extension
predictions_path, ground_truth_path
# Out:
# ('/content/drive/MyDrive/Colab_Notebooks/POLITO/Primer_anno/Machine_learning_and_deep_learning/Project/Test_models/juli_sample_200_nlq.json',
#  '/content/drive/MyDrive/Colab_Notebooks/POLITO/Primer_anno/Machine_learning_and_deep_learning/Project/egovlp_annotations/nlq_val.json')

# %%
import json
with open(predictions_path) as predictions_file, open(ground_truth_path) as ground_truth_file:
    predictions = json.load(predictions_file)
    ground_truths = json.load(ground_truth_file)

# %%
mIoUs = []
for prediction in predictions:
    for video in ground_truths['videos']:
        for clip in video['clips']:
            if clip['clip_uid'] == prediction['clip_uid']:
                for annotation in clip['annotations']:
                    if annotation['annotation_uid'] == prediction['annotation_uid']:
                        mIoUs.append({
                            'video_uid': video['video_uid'],
                            'clip_uid': clip['clip_uid'],
                            'annotation_uid': annotation['annotation_uid'],
                            'query_idx': prediction['query_idx'],
                            'clip_start_sec': annotation['language_queries'][prediction['query_idx']]['clip_start_sec'],
                            'clip_end_sec': annotation['language_queries'][prediction['query_idx']]['clip_end_sec'],
                            'mIoU': mIoU(
                                ground_truth=[
                                    annotation['language_queries'][prediction['query_idx']]['clip_start_sec'],
                                    annotation['language_queries'][prediction['query_idx']]['clip_end_sec']
                                    ],
                                predictions=prediction['predicted_times']),
                            'query': annotation['language_queries'][prediction['query_idx']]['query']

                        })
mIoUs
# Out:
# [{'video_uid': '3534864b-2289-4aaf-b3ed-10eeeee7acd2',
#   'clip_uid': 'bccc3bde-d9b2-4edb-9b1f-a3f42dd07b3e',
#   'annotation_uid': '1947bdf0-b455-4e1b-aefb-f952a834e4a5',
#   'query_idx': 6,
#   'clip_start_sec': 165.10395,
#   'clip_end_sec': 168.0,
#   'mIoU': 0.0,
#   'query': 'where is the yellow scooper?'},
#  {'video_uid': 'd8217a15-4527-4557-94c5-df4eb78b748a',
#   'clip_uid': 'ba265640-5261-4e3f-9b52-dda27d34898a',
#   'annotation_uid': '765eaaee-1f20-407e-ac10-6810c574d8d5',
#   'query_idx': 6,
#   'clip_start_sec': 402.92199,
#   'clip_end_sec': 421.666,
#   'mIoU': 0.0,
#   'query': 'Who did I interact with when adjusting a watch on the hand?'},
#  {'video_uid': '3534864b-2289-4aaf-b3ed-10eeeee7acd2',
#   'clip_uid': '8acaf6f6-5396-4df6-98e6-13baea8f8af8',
#   'annotation_uid': '37fabd23-dbd9-4a7d-9f33-d6507eb0fd76',
#   'query_idx': 26,
#   'clip_start_sec': 1194.70555,
#   'clip_end_sec': 1196.0,
#   'mIoU': 0.0,
#   'query': 'what dough shaper did i push?'},
#  {'video_uid': '7f70ae0a-d097-4dda-9afa-318188dfce2d',
#   'clip_uid': 'b2e24b02-4d9e-436e-8557-fe02b75c9f5f',
#   'annotation_uid': 'd3ddd7fd-8a3b-4201-b612-d9f78d9742ab',
#   'query_idx': 0,
#   'clip_start_sec': 0.0,
#   'clip_end_sec': 2.0,
#   'mIoU': 0.0,
#   'query': 'where were the asparagus before i picked them up'},
#  {'video_uid': '9e7fa594-5774-4681-a034-50a5c83cff8f',
#   'clip_uid': 'a8b49a23-cc44-47f9-ae8a-95584e537b8d',
#   'annotation_uid': '156c14c9-0c7a-4d40-b0bc-ab8e417f6438',
#   'query_idx': 4,
#   'clip_start_sec': 309.26636,
#   'clip_end_sec': 313.188,
#   'mIoU': 0.010401978261563027,
#   'query': 'in what location did I see the door rug '},
#  {'video_uid': '1c7426ad-b6ba-4494-897c-537dd4a201e9',
#   'clip_uid': '0aca0078-b6ab-41fb-9dc5-a70b8ad137b2',
#   'annotation_uid': 'd05845b4-cd60-4e38-b179-9b6c23ee6099',
#   'query_idx': 2,
#   'clip_start_sec': 284.8643,
#   'clip_end_sec': 295.97068,
#   'mIoU': 0.49694918323858894,
#   'query': 'How many tools did I pick from underneath the work table?'},
#  {'video_uid': '8912a138-6c68-424d-8be5-59e0d4f5c173',
#   'clip_uid': '810d230f-2771-4a2d-ad09-9b04714930d3',
#   'annotation_uid': '330a22b7-a72f-4cc4-bb28-6d007ce1ed68',
#   'query_idx': 5,
#   'clip_start_sec': 367.77272,
#   'clip_end_sec': 368.772,
#   'mIoU': 0.0006746194092826996,
#   'query': 'In what location did i see the sandals'},
#  {'video_uid': '168f91fd-53c2-4eee-9d2d-e25e1ad73438',
#   'clip_uid': '9466f5f0-09f2-4b9f-bb4a-3de270fd425b',
#   'annotation_uid': '8f1c9f14-22e7-4c6b-9906-9adbaaa82bf8',
#   'query_idx': 8,
#   'clip_start_sec': 402.1677,
#   'clip_end_sec': 480.067,
#   'mIoU': 0.06820505358552417,
#   'query': 'Where is the frame?'},
#  {'video_uid': '935f591f-9184-4ea8-869a-4c56d7029aa4',
#   'clip_uid': 'dcbafb3e-c8d1-43ce-a604-7662da9f2591',
#   'annotation_uid': '7fc66bc0-348b-4d23-a50f-8b735f4d297b',
#   'query_idx': 1,
#   'clip_start_sec': 66.9493,
#   'clip_end_sec': 70.59702,
#   'mIoU': 0.011014599337024514,
#   'query': 'Where is the glass jug?'},
#  {'video_uid': '80f3dd0d-6ad9-4691-9de5-dc01a834bc0a',
#   'clip_uid': '679cfee6-7da1-4701-b75a-9e34abb9400a',
#   'annotation_uid': 'a62a6082-2f04-48a5-a5ad-ddf8b2a07229',
#   'query_idx': 1,
#   'clip_start_sec': 41.84264,
#   'clip_end_sec': 45.842,
#   'mIoU': 0.415342718935099,
#   'query': 'Where was piece of wood before i picked it'},
#  {'video_uid': '85775377-b334-4bd7-8cfc-16885099cc9a',
#   'clip_uid': '35cd9ace-642f-4550-8e63-a5c2caae89ed',
#   'annotation_uid': 'cd65d2c2-8b2d-4873-989a-061b91be1bd8',
#   'query_idx': 2,
#   'clip_start_sec': 154.05798,
#   'clip_end_sec': 158.057,
#   'mIoU': 0.06133567788125367,
#   'query': 'Did I close the circuit breaker box? '},
#  {'video_uid': '86ebad37-486c-4687-b50e-67627a4be7a2',
#   'clip_uid': '3ef4d3b5-2a79-42f0-9609-509f886e7f93',
#   'annotation_uid': 'b8f6defe-914c-4fd4-8cc3-24e3f8a58f12',
#   'query_idx': 5,
#   'clip_start_sec': 303.48192,
#   'clip_end_sec': 304.33238,
#   'mIoU': 0.0009511723684210507,
#   'query': 'Where was the piece of paper before i picked it?'},
#  {'video_uid': '432cb803-6be5-47bc-8443-6bb5b9051667',
#   'clip_uid': 'cc6270fd-3c0d-4dda-bcb4-52cefc0224d7',
#   'annotation_uid': '2bc5aa4c-3114-497e-9d13-e229277fe11b',
#   'query_idx': 1,
#   'clip_start_sec': 41.39507,
#   'clip_end_sec': 43.879,
#   'mIoU': 0.0027035972789115656,
#   'query': 'Where did I put the bucket?'},
#  {'video_uid': 'f324ccbc-bef5-4d68-9722-cc99bdaaa660',
#   'clip_uid': '5e59031d-0deb-4557-a3e1-ba0ba2bb5465',
#   'annotation_uid': 'efc826dc-9abe-4ecc-a1bd-685e58b62d90',
#   'query_idx': 13,
#   'clip_start_sec': 1138.57323,
#   'clip_end_sec': 1140.0,
#   'mIoU': 0.0,
#   'query': 'Where did I put the detergent?'},
#  {'video_uid': '939dcf5d-c88c-4f93-b300-982adaff5ce3',
#   'clip_uid': 'fc4bfef7-e079-4783-92e1-b768cfac8125',
#   'annotation_uid': '6f2fcdde-43ad-46f9-8778-40659a86218d',
#   'query_idx': 4,
#   'clip_start_sec': 399.70651,
#   'clip_end_sec': 402.75195,
#   'mIoU': 0.0,
#   'query': 'Did I switch off the mower'},
#  {'video_uid': '5935de98-30c0-4357-9e89-1c1395c1e2c1',
#   'clip_uid': 'e722f056-dc03-4de5-a861-e379f513b004',
#   'annotation_uid': 'ece2ca6e-19d4-4222-8047-854c6f09f23e',
#   'query_idx': 1,
#   'clip_start_sec': 111.8039,
#   'clip_end_sec': 112.63898,
#   'mIoU': 0.0023140318488529153,
#   'query': 'what did I put on  the kitchen slab?'},
#  {'video_uid': '0c6ab491-c45e-4cbc-b6b2-a709cc856a9c',
#   'clip_uid': '71e0d3e7-4706-4eb3-9a7a-85d01f46259f',
#   'annotation_uid': 'd6111b4f-0b33-431c-bc69-4873edc4ff12',
#   'query_idx': 6,
#   'clip_start_sec': 359.3743,
#   'clip_end_sec': 382.45465,
#   'mIoU': 0.16241536939264886,
#   'query': 'Where are my glasses'},
#  {'video_uid': '5afd7421-fb6b-4c65-a09a-716f79a7a935',
#   'clip_uid': '67db788f-6307-416f-8385-d4053e5777b9',
#   'annotation_uid': '406dfeda-3276-4bab-b495-12acad39afad',
#   'query_idx': 2,
#   'clip_start_sec': 99.45426,
#   'clip_end_sec': 100.0,
#   'mIoU': 0.019176049382715873,
#   'query': 'where was the screwdriver before i took it?'},
#  {'video_uid': '512db5d5-6aa3-4777-a1ba-1ea1718db929',
#   'clip_uid': '1c865785-9ac6-4f16-baa4-97405aacad6a',
#   'annotation_uid': '61110650-804f-4d64-8753-f5d4023133ac',
#   'query_idx': 6,
#   'clip_start_sec': 297.17024,
#   'clip_end_sec': 298.81887,
#   'mIoU': 0.0,
#   'query': 'Where is the can after I dropped it ?'},
#  {'video_uid': 'c864505c-9d49-4da4-bf7e-254b4c348c03',
#   'clip_uid': '96453857-2454-418f-bbd6-3f5f8b3eadbd',
#   'annotation_uid': 'a23e1d01-7ac4-47f1-ac6e-3c66ebe78447',
#   'query_idx': 9,
#   'clip_start_sec': 376.92763,
#   'clip_end_sec': 377.819,
#   'mIoU': 0.000764294524793384,
#   'query': 'Did i close the ice cube shelf?'},
#  {'video_uid': '624a6c0a-a4cb-4073-b501-48e4b6b679e4',
#   'clip_uid': '903e0bf6-db7e-4b1c-8cb9-867317963fde',
#   'annotation_uid': '3a8dc748-9cdb-47ba-988e-87bdc446368e',
#   'query_idx': 2,
#   'clip_start_sec': 138.301,
#   'clip_end_sec': 142.301,
#   'mIoU': 0.008526645768025079,
#   'query': 'Where did I put the hammer?'},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': '75958c37-1002-4b2d-a455-168b0ebcaf8a',
#   'annotation_uid': '69ba2583-8c8b-41e0-8294-a7f61a71727e',
#   'query_idx': 4,
#   'clip_start_sec': 147.30506,
#   'clip_end_sec': 154.305,
#   'mIoU': 0.47865210958408444,
#   'query': 'What color is the cloth i folded?'},
#  {'video_uid': 'bbd117a9-e969-4e15-9840-70101a864dd5',
#   'clip_uid': '1ff34d9f-1c5a-40d8-98ee-8d3cbf48ebc3',
#   'annotation_uid': '80064f7f-ba68-4316-8f8f-d7934fc7694e',
#   'query_idx': 0,
#   'clip_start_sec': 1.78944,
#   'clip_end_sec': 23.0,
#   'mIoU': 0.0,
#   'query': 'Where is the pack of vegetable?'},
#  {'video_uid': '86ebad37-486c-4687-b50e-67627a4be7a2',
#   'clip_uid': '3ef4d3b5-2a79-42f0-9609-509f886e7f93',
#   'annotation_uid': 'b8f6defe-914c-4fd4-8cc3-24e3f8a58f12',
#   'query_idx': 5,
#   'clip_start_sec': 303.48192,
#   'clip_end_sec': 304.33238,
#   'mIoU': 0.0009511723684210507,
#   'query': 'Where was the piece of paper before i picked it?'},
#  {'video_uid': '939dcf5d-c88c-4f93-b300-982adaff5ce3',
#   'clip_uid': 'fc4bfef7-e079-4783-92e1-b768cfac8125',
#   'annotation_uid': '6f2fcdde-43ad-46f9-8778-40659a86218d',
#   'query_idx': 2,
#   'clip_start_sec': 36.42862,
#   'clip_end_sec': 39.17055,
#   'mIoU': 0.020310592592592568,
#   'query': 'Did I leave the rod standing.'},
#  {'video_uid': 'bd3a319e-0573-4802-a6d1-6d89910098e8',
#   'clip_uid': 'a35ac9e4-bb20-460e-9c9d-67806ab9d13f',
#   'annotation_uid': '0faae1b8-380e-43a1-9868-b5c847a5a8f1',
#   'query_idx': 3,
#   'clip_start_sec': 141.2592,
#   'clip_end_sec': 141.2592,
#   'mIoU': 0.014384477929102676,
#   'query': 'who did I interact with when I was picked  snack?'},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': '70cef020-51e7-429e-af75-f87747b3daad',
#   'annotation_uid': '3529aee9-4752-4d79-8fec-1b9343b81295',
#   'query_idx': 4,
#   'clip_start_sec': 285.0,
#   'clip_end_sec': 289.0,
#   'mIoU': 0.01834694096217722,
#   'query': 'what did I put in the plastic container?'},
#  {'video_uid': '243e800d-fc75-473d-b944-a95844e13a78',
#   'clip_uid': '2c2bda8d-69a3-4a90-9ad6-f6715bc99f39',
#   'annotation_uid': 'c7377c33-3b3d-4447-9459-1becffdfc106',
#   'query_idx': 3,
#   'clip_start_sec': 192.25264,
#   'clip_end_sec': 193.18593,
#   'mIoU': 0.05347033784615381,
#   'query': 'What electronic gadget did I pick?'},
#  {'video_uid': '1938c632-f575-49dd-8ae0-e48dbb467920',
#   'clip_uid': '7db32b15-9ea6-4a44-a103-cc04471ce4f7',
#   'annotation_uid': 'c44e960a-8c34-432c-acc9-5c25963af193',
#   'query_idx': 1,
#   'clip_start_sec': 71.17935,
#   'clip_end_sec': 75.0,
#   'mIoU': 0.011986352941176472,
#   'query': 'how many eggs did I pick?'},
#  {'video_uid': 'c0f702e1-d2e3-4277-8981-7177d106174a',
#   'clip_uid': '8bf16989-e870-44bb-863c-c6745e69f6fb',
#   'annotation_uid': '0bc1549b-fd67-4166-8ba2-4019975312af',
#   'query_idx': 5,
#   'clip_start_sec': 302.99422,
#   'clip_end_sec': 315.994,
#   'mIoU': 0.04054251279911223,
#   'query': 'where was the machete before I picked it?'},
#  {'video_uid': '94cdabf3-c078-4ad4-a3a1-c42c8fc3f4ad',
#   'clip_uid': 'b01fdd44-357c-4566-b487-d9ff21e56c2e',
#   'annotation_uid': '7ae246f9-e526-454e-b655-ef0d9276fe22',
#   'query_idx': 1,
#   'clip_start_sec': 75.22579,
#   'clip_end_sec': 83.13353,
#   'mIoU': 0.0,
#   'query': 'What did I remove from the plastic wrap?'},
#  {'video_uid': '0971527a-6cd3-4c82-9d94-09b3565f4505',
#   'clip_uid': '755ac5c3-b6cd-42da-ac72-c413d0be986a',
#   'annotation_uid': 'c3e465af-6e74-4309-aa04-8bb923ea85e0',
#   'query_idx': 6,
#   'clip_start_sec': 464.53621,
#   'clip_end_sec': 467.31073,
#   'mIoU': 0.0,
#   'query': 'Where is the bucket'},
#  {'video_uid': '3ee7070a-fe81-49a9-97a2-902268af9985',
#   'clip_uid': 'a40dce18-488d-4acc-b754-fcd56c204db1',
#   'annotation_uid': '617f76c2-b046-4be0-b44b-e49439b0e416',
#   'query_idx': 5,
#   'clip_start_sec': 261.78895,
#   'clip_end_sec': 262.931,
#   'mIoU': 0.07118982996785568,
#   'query': 'Where was the towel?'},
#  {'video_uid': '9bf859f2-62ff-4f2e-9eb8-ef69feb4d343',
#   'clip_uid': 'ca304360-2402-4241-a6eb-5ff2f300546f',
#   'annotation_uid': '994f38c0-b2b8-4677-8bb1-10955188c558',
#   'query_idx': 2,
#   'clip_start_sec': 135.0,
#   'clip_end_sec': 146.0,
#   'mIoU': 0.014023430728894296,
#   'query': 'what color was the file?'},
#  {'video_uid': 'f082242c-309f-48a1-97fa-5c1d6bd255fb',
#   'clip_uid': '5d531ac1-010a-4e67-ba1a-96e485b14968',
#   'annotation_uid': '3eb83361-fc41-4f9c-bb0c-978bebbf1175',
#   'query_idx': 2,
#   'clip_start_sec': 49.0,
#   'clip_end_sec': 51.7,
#   'mIoU': 0.0,
#   'query': 'Where was the knife before I picked it ?'},
#  {'video_uid': 'f2a257e6-01da-4856-b145-2947ce5dcb0e',
#   'clip_uid': '498d6197-deb0-481c-9cfd-8d516122638d',
#   'annotation_uid': '31be573d-9c1a-4d9b-8200-7e81157cd3ca',
#   'query_idx': 0,
#   'clip_start_sec': 0.0,
#   'clip_end_sec': 1.62346,
#   'mIoU': 0.09053064553531989,
#   'query': 'Where was the hacksaw before I picked it ? '},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': '58fa07ae-2992-4dc9-842a-e5a73ee3d345',
#   'annotation_uid': '1cf514d5-81b8-47b6-b378-d3efa5829592',
#   'query_idx': 4,
#   'clip_start_sec': 249.81585,
#   'clip_end_sec': 253.51039,
#   'mIoU': 0.0,
#   'query': 'where wass the dustbin'},
#  {'video_uid': '824e7896-904a-4ff5-b7ee-e21df21918c2',
#   'clip_uid': 'e8842ef9-1d09-4393-ba98-ad18800c6f3e',
#   'annotation_uid': 'fd3c3693-1eef-4b96-bb4a-72361856b371',
#   'query_idx': 3,
#   'clip_start_sec': 360.78731,
#   'clip_end_sec': 374.3276,
#   'mIoU': 0.0,
#   'query': 'Where is the cutting board?'},
#  {'video_uid': '824e7896-904a-4ff5-b7ee-e21df21918c2',
#   'clip_uid': 'da0092ba-0247-4438-9172-4f60f00be608',
#   'annotation_uid': 'f5a0f3fe-dfd0-4b08-b913-79b55841b56b',
#   'query_idx': 7,
#   'clip_start_sec': 234.49205,
#   'clip_end_sec': 236.94273,
#   'mIoU': 0.0,
#   'query': 'Did I leave the tap open?'},
#  {'video_uid': 'c8d88b2c-d6ed-4ef3-a7a1-e3b3dac0550f',
#   'clip_uid': 'cc2a687e-e871-4319-85c9-c0161678903d',
#   'annotation_uid': '3d910daf-00b9-4951-8927-685c7c2f9158',
#   'query_idx': 0,
#   'clip_start_sec': 81.35669,
#   'clip_end_sec': 81.67481,
#   'mIoU': 0.0,
#   'query': 'Who did I talk to in the living room?'},
#  {'video_uid': 'd526d862-080f-4b3e-9894-6ff997f5d6ac',
#   'clip_uid': 'b69e6150-0309-4202-bf4a-9a342f80d6d7',
#   'annotation_uid': 'cfa46eb6-259c-4591-8e1e-0c748dd68bad',
#   'query_idx': 1,
#   'clip_start_sec': 23.95484,
#   'clip_end_sec': 27.22756,
#   'mIoU': 0.23437339092678613,
#   'query': 'What color is the colander?'},
#  {'video_uid': '6243586b-a8df-4c37-95f8-da7f4f5d57d6',
#   'clip_uid': 'b352dc19-c601-4740-9559-6db99ea782e9',
#   'annotation_uid': 'ebee2c27-b4e6-4ed2-a2ea-c2360d025cf0',
#   'query_idx': 3,
#   'clip_start_sec': 269.34156,
#   'clip_end_sec': 270.265,
#   'mIoU': 0.06550963204500737,
#   'query': 'Where did I take a packet from?'},
#  {'video_uid': 'c0f702e1-d2e3-4277-8981-7177d106174a',
#   'clip_uid': '8bf16989-e870-44bb-863c-c6745e69f6fb',
#   'annotation_uid': '0bc1549b-fd67-4166-8ba2-4019975312af',
#   'query_idx': 4,
#   'clip_start_sec': 269.8815,
#   'clip_end_sec': 269.8815,
#   'mIoU': 0.013610676030361068,
#   'query': 'what was the color of the hoe?'},
#  {'video_uid': '0971527a-6cd3-4c82-9d94-09b3565f4505',
#   'clip_uid': '755ac5c3-b6cd-42da-ac72-c413d0be986a',
#   'annotation_uid': 'f35a2b55-622a-433e-a218-90769e474831',
#   'query_idx': 3,
#   'clip_start_sec': 178.31767,
#   'clip_end_sec': 187.0,
#   'mIoU': 0.00942761610962568,
#   'query': 'Where did I put the cable ties?'},
#  {'video_uid': '18a3840b-7463-43c4-9aa9-b1d8e486fa84',
#   'clip_uid': 'a538b7bc-5ec2-496a-8bbe-9d6d38381a39',
#   'annotation_uid': 'f5f878e3-60dd-4ee1-8080-a11774ba3294',
#   'query_idx': 1,
#   'clip_start_sec': 90.3572,
#   'clip_end_sec': 101.76579,
#   'mIoU': 0.10937106653814861,
#   'query': 'Where did I throw the bottle I drank from?'},
#  {'video_uid': '624a6c0a-a4cb-4073-b501-48e4b6b679e4',
#   'clip_uid': 'a611f8f9-a866-4b40-a9c6-34175a62f178',
#   'annotation_uid': '8d8266f3-f317-4f7c-bb89-797656be03df',
#   'query_idx': 0,
#   'clip_start_sec': 12.67211,
#   'clip_end_sec': 23.672,
#   'mIoU': 0.16054679842636882,
#   'query': 'What tool did I use on the engine?'},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': 'f748feb9-9a15-4f2b-9b65-186f90107c7c',
#   'annotation_uid': 'ed904e38-6e0e-4e4e-9bfe-d4b28127fde4',
#   'query_idx': 12,
#   'clip_start_sec': 1097.18994,
#   'clip_end_sec': 1102.69444,
#   'mIoU': 0.18680406268581531,
#   'query': 'What did I bring out of the fridge'},
#  {'video_uid': '25beabfc-48c0-4f81-b419-c47297aecf6f',
#   'clip_uid': 'c9885f38-fa92-42f0-b998-42b1139b5b5f',
#   'annotation_uid': '1e25aa63-50aa-4039-953f-324bea8c3f72',
#   'query_idx': 0,
#   'clip_start_sec': 131.86819,
#   'clip_end_sec': 172.00473,
#   'mIoU': 0.08696057258093051,
#   'query': 'Who did I interact with when I coupled the disc cutter saw?'},
#  {'video_uid': 'e0c4d2c7-fd50-4c50-b40e-e1eda4a5708b',
#   'clip_uid': 'aa2afb03-41d8-42fc-a111-982d9319f1c4',
#   'annotation_uid': '85d10fda-c58f-4e67-b593-2c53e28038b5',
#   'query_idx': 4,
#   'clip_start_sec': 290.26702,
#   'clip_end_sec': 294.5247,
#   'mIoU': 0.0023196821351316715,
#   'query': 'Where did I put the glass cup?'},
#  {'video_uid': '603ecf93-d2c1-4611-a690-76afd18935c8',
#   'clip_uid': 'cf1470f1-9a03-4944-95dd-7f8410bb6cc8',
#   'annotation_uid': '1ba5bf7a-bb9e-4594-b679-da6f7c52a05a',
#   'query_idx': 1,
#   'clip_start_sec': 69.056,
#   'clip_end_sec': 70.256,
#   'mIoU': 0.0013473684210526349,
#   'query': 'Where was the black container before I picked it up?'},
#  {'video_uid': 'eb81442c-a322-49ea-b243-a39d2e288b9b',
#   'clip_uid': 'd22d3eaf-9350-46b9-99d0-39fb50e246c0',
#   'annotation_uid': 'bbbec6de-db2c-440a-9f40-3999be74370e',
#   'query_idx': 1,
#   'clip_start_sec': 189.04035,
#   'clip_end_sec': 189.04035,
#   'mIoU': 0.011388376629755939,
#   'query': 'Where did I put a stone'},
#  {'video_uid': 'fec1f883-fc5c-4257-985e-26efaec68ddc',
#   'clip_uid': '53c86be4-190d-4410-8750-179a7edc70b3',
#   'annotation_uid': '53f3aa88-cbbc-4672-8823-fdb5edc61390',
#   'query_idx': 7,
#   'clip_start_sec': 722.23741,
#   'clip_end_sec': 723.0,
#   'mIoU': 0.00046154340442658697,
#   'query': 'Did I leave the door open?'},
#  {'video_uid': 'f6a0d8f5-468d-4e47-bfca-e7d13b75f26d',
#   'clip_uid': '81ad10fe-c74e-4359-8779-186f46680e2c',
#   'annotation_uid': '62c40b8f-fd95-43f9-9b00-cb253c0abc2c',
#   'query_idx': 6,
#   'clip_start_sec': 404.45524,
#   'clip_end_sec': 415.236,
#   'mIoU': 0.009779735678078067,
#   'query': 'What did i pour into the steel bowl ?'},
#  {'video_uid': '42c08776-8832-4d37-8844-3ce89e405c62',
#   'clip_uid': 'f15dbeca-63e7-43b5-b1a6-7896bc28b08c',
#   'annotation_uid': '08a04c87-bb88-4cc0-9f4f-8760931d3996',
#   'query_idx': 4,
#   'clip_start_sec': 181.39365,
#   'clip_end_sec': 209.0,
#   'mIoU': 0.0,
#   'query': 'where did l saw the dummy doll'},
#  {'video_uid': '235b49d2-b59c-4079-81cc-ad9c01dbd2df',
#   'clip_uid': 'b5ae8df0-4825-4021-a01a-722947019865',
#   'annotation_uid': '9c19c66b-0b81-4a8e-a9af-896261e38263',
#   'query_idx': 1,
#   'clip_start_sec': 83.85124,
#   'clip_end_sec': 87.4,
#   'mIoU': 0.03857264441546864,
#   'query': 'Where was the stool before I picked it'},
#  {'video_uid': 'c40736ec-e68f-43f6-960d-7d8bd467b1c7',
#   'clip_uid': '89193dbc-0ffa-4ee2-9ea8-c434ce177310',
#   'annotation_uid': 'dc31cf2a-4584-4122-86f1-488ada791faf',
#   'query_idx': 0,
#   'clip_start_sec': 2.4326,
#   'clip_end_sec': 4.0,
#   'mIoU': 0.12088719088671944,
#   'query': 'Where was the stainless bowl before I picked it up?'},
#  {'video_uid': '1dcc108c-8bd4-42ad-b2c5-03662be62eda',
#   'clip_uid': '47c24350-cc10-4ec6-8407-24f778981a82',
#   'annotation_uid': '59f62bf1-b6cf-4417-9388-18dc2e02c976',
#   'query_idx': 0,
#   'clip_start_sec': 10.0,
#   'clip_end_sec': 12.0,
#   'mIoU': 0.2339148238357341,
#   'query': 'Where did I close the car door?'},
#  {'video_uid': '51fc62f8-00f4-44e3-af9c-7ebb63da6c3d',
#   'clip_uid': 'c7accb5b-fc3c-415b-986e-59643d94cdc6',
#   'annotation_uid': 'f9184458-9051-46d1-9e24-840f40504045',
#   'query_idx': 3,
#   'clip_start_sec': 40.84447,
#   'clip_end_sec': 42.04447,
#   'mIoU': 0.0017297297297297234,
#   'query': 'where did I put the bowl?'},
#  {'video_uid': 'cd7c3bc6-24df-465c-9b63-a7961a7558de',
#   'clip_uid': 'c664f078-9b34-4a58-b949-180ac4bc0980',
#   'annotation_uid': 'f4dcaa0b-92a0-4168-ac6b-ad7df26d8a15',
#   'query_idx': 2,
#   'clip_start_sec': 88.27018,
#   'clip_end_sec': 90.0,
#   'mIoU': 0.0008164342182890872,
#   'query': 'what did I pick from the wall'},
#  {'video_uid': '7d6d6cae-0601-485d-b900-482b4254e9f8',
#   'clip_uid': '5bff21b4-ac93-450f-a189-b2fb7cff4d99',
#   'annotation_uid': '89e5cc1e-500c-4452-9a3f-2d9e02cb8396',
#   'query_idx': 7,
#   'clip_start_sec': 58.66908,
#   'clip_end_sec': 60.97166,
#   'mIoU': 0.17410761321713888,
#   'query': 'Where did I put the phone'},
#  {'video_uid': '18a3840b-7463-43c4-9aa9-b1d8e486fa84',
#   'clip_uid': 'a538b7bc-5ec2-496a-8bbe-9d6d38381a39',
#   'annotation_uid': '36e9d168-44dc-43e7-8189-13a7fbfe64bc',
#   'query_idx': 5,
#   'clip_start_sec': 247.0,
#   'clip_end_sec': 248.0,
#   'mIoU': 0.0006993006993006993,
#   'query': 'In what location did I see the hacksaw?'},
#  {'video_uid': '245cde61-d0a0-49c8-840d-e484b5f71a04',
#   'clip_uid': '12babcc1-a848-4882-869e-b6e8cc963c2c',
#   'annotation_uid': '9473d9e3-8872-4944-904f-5755a9b831a9',
#   'query_idx': 7,
#   'clip_start_sec': 372.2871,
#   'clip_end_sec': 398.9827,
#   'mIoU': 0.0,
#   'query': 'Where was the pot lid before I covered the pot?'},
#  {'video_uid': '404cc1c1-f7a0-4e16-9a39-b8e2d5d9ae59',
#   'clip_uid': '1c597fc1-7bd0-4325-abbc-645e3ec71866',
#   'annotation_uid': '5f5ccaa6-6b65-4f5c-b2f3-57d5ad659fc1',
#   'query_idx': 7,
#   'clip_start_sec': 323.54713,
#   'clip_end_sec': 325.90154,
#   'mIoU': 0.0,
#   'query': 'How many rolls of paper towel did I cut'},
#  {'video_uid': '216c7a1a-7ec3-4aa0-a465-e37e7b5fd2f3',
#   'clip_uid': '093259bc-5b71-4204-be7b-5f7b5b5f20cb',
#   'annotation_uid': '5ecca0b5-c8b3-4e76-8332-712f83bf9b90',
#   'query_idx': 5,
#   'clip_start_sec': 601.438,
#   'clip_end_sec': 603.438,
#   'mIoU': 0.0008939645557627766,
#   'query': 'What machine did I touch in the house?'},
#  {'video_uid': 'bd3a319e-0573-4802-a6d1-6d89910098e8',
#   'clip_uid': 'a35ac9e4-bb20-460e-9c9d-67806ab9d13f',
#   'annotation_uid': '0faae1b8-380e-43a1-9868-b5c847a5a8f1',
#   'query_idx': 1,
#   'clip_start_sec': 81.33784,
#   'clip_end_sec': 81.33784,
#   'mIoU': 0.3520153013061368,
#   'query': 'where was coke before I picked it?'},
#  {'video_uid': '6243586b-a8df-4c37-95f8-da7f4f5d57d6',
#   'clip_uid': 'b352dc19-c601-4740-9559-6db99ea782e9',
#   'annotation_uid': 'ebee2c27-b4e6-4ed2-a2ea-c2360d025cf0',
#   'query_idx': 1,
#   'clip_start_sec': 206.68845,
#   'clip_end_sec': 207.97,
#   'mIoU': 0.0,
#   'query': 'What did I take from the shelf hook '},
#  {'video_uid': '0dbd615d-fde9-4936-a605-6f5659cd113e',
#   'clip_uid': '7c1f3062-ae3e-4db0-b490-940cc2a7b949',
#   'annotation_uid': 'cd803af4-846c-422a-9c13-bda6a4df49d8',
#   'query_idx': 3,
#   'clip_start_sec': 281.02744,
#   'clip_end_sec': 282.866,
#   'mIoU': 0.0032323896741175105,
#   'query': 'How many pieces of cups are ion top of the fridge?'},
#  {'video_uid': '4ce119de-0f42-4bd1-b387-9e19643fdddc',
#   'clip_uid': 'e1c79556-e8af-4e26-bc4c-633100277239',
#   'annotation_uid': 'd8fb0c3d-39b1-4bb2-b800-fc56f12ab120',
#   'query_idx': 8,
#   'clip_start_sec': 381.26346,
#   'clip_end_sec': 390.66762,
#   'mIoU': 0.011626874285985536,
#   'query': 'Where was the microwave?'},
#  {'video_uid': 'e98dd5f7-e90e-484e-b8ae-9a180882a26d',
#   'clip_uid': '1d122be0-830e-42ca-a6a4-b8ae67b0e3bc',
#   'annotation_uid': '49188ec2-6b41-4673-85a9-2e7204757057',
#   'query_idx': 4,
#   'clip_start_sec': 327.39086,
#   'clip_end_sec': 328.0,
#   'mIoU': 0.0006346956803029825,
#   'query': 'Where did I put the black torch?'},
#  {'video_uid': '45a02f60-e694-4bef-9c31-d5a71f556122',
#   'clip_uid': 'c6470548-81a3-4d9c-8bee-87a955948d5c',
#   'annotation_uid': '861763f7-591e-4f0e-8244-d91f2f7e0243',
#   'query_idx': 0,
#   'clip_start_sec': 1.08028,
#   'clip_end_sec': 5.08,
#   'mIoU': 0.016087673427041503,
#   'query': 'where did the car pass before I started walking'},
#  {'video_uid': '42c08776-8832-4d37-8844-3ce89e405c62',
#   'clip_uid': 'f15dbeca-63e7-43b5-b1a6-7896bc28b08c',
#   'annotation_uid': '08a04c87-bb88-4cc0-9f4f-8760931d3996',
#   'query_idx': 2,
#   'clip_start_sec': 11.7226,
#   'clip_end_sec': 17.0,
#   'mIoU': 0.25478013760887014,
#   'query': 'who did l talk to in front of the boutique store'},
#  {'video_uid': 'f442873e-6f2b-493f-a6db-718cd20a732a',
#   'clip_uid': '055a1e31-aa3f-4695-a8ee-6c0c6351c936',
#   'annotation_uid': '5616defe-9963-4c08-95da-03ce3d28bf94',
#   'query_idx': 5,
#   'clip_start_sec': 420.09955,
#   'clip_end_sec': 421.0,
#   'mIoU': 0.013865390769230431,
#   'query': 'where did I put the phone?'},
#  {'video_uid': '82ace2ff-4a87-4abe-ba45-3965bbc13658',
#   'clip_uid': 'e9becd62-c5ea-4104-9d81-781a78bb7dbe',
#   'annotation_uid': '5f5e4631-c34d-46c2-b1cd-f7504e0c06df',
#   'query_idx': 2,
#   'clip_start_sec': 5.23825,
#   'clip_end_sec': 8.47592,
#   'mIoU': 0.01484023295582601,
#   'query': 'What did I put in the Oven?'},
#  {'video_uid': 'b68709fe-2a73-49c3-a468-afcf56ab234c',
#   'clip_uid': '6e73e4ca-d147-40ea-8587-035e8f2850c7',
#   'annotation_uid': 'cc629689-4f0f-479f-a946-805808f3cf7d',
#   'query_idx': 9,
#   'clip_start_sec': 623.59334,
#   'clip_end_sec': 626.77386,
#   'mIoU': 0.0,
#   'query': 'What tool did I pick from the table?'},
#  {'video_uid': '182dffe9-d2bf-4a7d-b1d8-137470f0143d',
#   'clip_uid': 'cab983c1-d36e-4afa-8116-1e2bde4a4a4c',
#   'annotation_uid': '8bca6b25-cac7-4947-9cf0-2254113e8697',
#   'query_idx': 0,
#   'clip_start_sec': 17.51421,
#   'clip_end_sec': 20.666,
#   'mIoU': 0.0,
#   'query': 'Where was the chopping board before i picked it?'},
#  {'video_uid': '7d6d6cae-0601-485d-b900-482b4254e9f8',
#   'clip_uid': '5bff21b4-ac93-450f-a189-b2fb7cff4d99',
#   'annotation_uid': '1414e946-774f-4d94-99e3-8b72d2bfe930',
#   'query_idx': 7,
#   'clip_start_sec': 442.0,
#   'clip_end_sec': 475.0,
#   'mIoU': 0.0,
#   'query': 'Where was the hair brush?'},
#  {'video_uid': '53da674a-089d-428a-a719-e322b2de002b',
#   'clip_uid': '5438349a-2d91-4d73-b763-f10f04c77d37',
#   'annotation_uid': '086f0f77-d388-47a8-a8ac-2bd81b834b90',
#   'query_idx': 5,
#   'clip_start_sec': 320.73651,
#   'clip_end_sec': 329.0,
#   'mIoU': 0.006037252968036522,
#   'query': 'where is the dough'},
#  {'video_uid': '3fc60e72-91ad-4320-bd07-1cf753f4a5f1',
#   'clip_uid': '740a9d13-cf77-4e7d-91b5-a3ebf6d270ec',
#   'annotation_uid': 'ba973d7d-473e-4df9-955b-d590cd9436f8',
#   'query_idx': 0,
#   'clip_start_sec': 442.95713,
#   'clip_end_sec': 449.836,
#   'mIoU': 0.4321734457344716,
#   'query': 'who did I talk to at the walkway?'},
#  {'video_uid': 'd526d862-080f-4b3e-9894-6ff997f5d6ac',
#   'clip_uid': 'b69e6150-0309-4202-bf4a-9a342f80d6d7',
#   'annotation_uid': 'b1d8a893-a87e-4b7a-8a1c-9b8f8fde9f41',
#   'query_idx': 14,
#   'clip_start_sec': 393.88749,
#   'clip_end_sec': 393.88749,
#   'mIoU': 0.015815513626834383,
#   'query': 'where is my pipe metal?'},
#  {'video_uid': 'fec1f883-fc5c-4257-985e-26efaec68ddc',
#   'clip_uid': '53c86be4-190d-4410-8750-179a7edc70b3',
#   'annotation_uid': '6e530270-92ce-4518-b45a-94fe5aabf02f',
#   'query_idx': 10,
#   'clip_start_sec': 785.11291,
#   'clip_end_sec': 795.65722,
#   'mIoU': 0.0018140748387096765,
#   'query': 'What color was the wristwatch I wore?'},
#  {'video_uid': '86343e9e-b932-41d3-ad6f-83f2c2fe5486',
#   'clip_uid': '4ba774a8-cd2a-4889-9971-cc91f5c1afd4',
#   'annotation_uid': 'c0d973f1-9c48-4268-bc4a-db8062199894',
#   'query_idx': 5,
#   'clip_start_sec': 190.0,
#   'clip_end_sec': 193.0,
#   'mIoU': 0.138,
#   'query': 'Where Was the plate before I picked it?'},
#  {'video_uid': '25beabfc-48c0-4f81-b419-c47297aecf6f',
#   'clip_uid': 'c9885f38-fa92-42f0-b998-42b1139b5b5f',
#   'annotation_uid': '1e25aa63-50aa-4039-953f-324bea8c3f72',
#   'query_idx': 0,
#   'clip_start_sec': 131.86819,
#   'clip_end_sec': 172.00473,
#   'mIoU': 0.08696057258093051,
#   'query': 'Who did I interact with when I coupled the disc cutter saw?'},
#  {'video_uid': '805989f6-0696-4de2-ad9b-0f194e0ac48d',
#   'clip_uid': 'eaf8d34a-0e20-45d0-a288-569df047461e',
#   'annotation_uid': '2ce0dc4d-d51a-4a07-93a1-fe0c3fdc3c78',
#   'query_idx': 7,
#   'clip_start_sec': 6.3983,
#   'clip_end_sec': 6.3983,
#   'mIoU': 0.020037537537537536,
#   'query': 'Where did i put the bolt'},
#  {'video_uid': 'ad851441-1f15-467e-83d8-48c764e220a8',
#   'clip_uid': '6c2849cb-d6bb-432e-b4ae-8b8c4837ad8b',
#   'annotation_uid': '5925d86c-d9f1-4430-85e2-0161ef01ae74',
#   'query_idx': 4,
#   'clip_start_sec': 467.89268,
#   'clip_end_sec': 474.04765,
#   'mIoU': 0.004264844374308097,
#   'query': 'Where is the luggage?'},
#  {'video_uid': 'bedaa131-deae-4279-9fd4-5b6ab552644c',
#   'clip_uid': 'eceaedd8-2560-441c-a084-214db47d509a',
#   'annotation_uid': '24a91700-0ec3-4b36-9e0e-1668253a463f',
#   'query_idx': 3,
#   'clip_start_sec': 132.42393,
#   'clip_end_sec': 159.0,
#   'mIoU': 0.0873508037209302,
#   'query': 'in what location did l use wrench '},
#  {'video_uid': 'd526d862-080f-4b3e-9894-6ff997f5d6ac',
#   'clip_uid': 'b69e6150-0309-4202-bf4a-9a342f80d6d7',
#   'annotation_uid': 'b1d8a893-a87e-4b7a-8a1c-9b8f8fde9f41',
#   'query_idx': 1,
#   'clip_start_sec': 13.585,
#   'clip_end_sec': 13.585,
#   'mIoU': 0.0,
#   'query': 'what did  I  put in the  bucket?'},
#  {'video_uid': '3534864b-2289-4aaf-b3ed-10eeeee7acd2',
#   'clip_uid': '8acaf6f6-5396-4df6-98e6-13baea8f8af8',
#   'annotation_uid': '37fabd23-dbd9-4a7d-9f33-d6507eb0fd76',
#   'query_idx': 1,
#   'clip_start_sec': 28.66799,
#   'clip_end_sec': 28.66799,
#   'mIoU': 0.07518719561971747,
#   'query': 'Where did i put the lid?'},
#  {'video_uid': '45a02f60-e694-4bef-9c31-d5a71f556122',
#   'clip_uid': 'c6470548-81a3-4d9c-8bee-87a955948d5c',
#   'annotation_uid': '861763f7-591e-4f0e-8244-d91f2f7e0243',
#   'query_idx': 1,
#   'clip_start_sec': 6.87213,
#   'clip_end_sec': 11.872,
#   'mIoU': 0.0,
#   'query': 'where is the tent?'},
#  {'video_uid': '06fb8090-16a4-42c3-819e-f0e95ddba24d',
#   'clip_uid': '5d466470-4de6-4318-9806-f5a0c24807de',
#   'annotation_uid': 'a3a64d6f-f22c-4fee-8979-7b9fa82d1ccb',
#   'query_idx': 0,
#   'clip_start_sec': 157.72822,
#   'clip_end_sec': 158.49429,
#   'mIoU': 0.000389547751469894,
#   'query': 'where was pantry pack before I picked it?'},
#  {'video_uid': '45a02f60-e694-4bef-9c31-d5a71f556122',
#   'clip_uid': 'c6470548-81a3-4d9c-8bee-87a955948d5c',
#   'annotation_uid': 'b11c94db-3574-4d78-906c-da6a9b659c8a',
#   'query_idx': 3,
#   'clip_start_sec': 194.70449,
#   'clip_end_sec': 203.83524,
#   'mIoU': 0.010212023026315797,
#   'query': 'How many tents?'},
#  {'video_uid': 'c864505c-9d49-4da4-bf7e-254b4c348c03',
#   'clip_uid': '89f7ac43-956d-4d7e-b8a1-442ecff20ad6',
#   'annotation_uid': '68b2d5c2-8740-496b-8221-baedfde09087',
#   'query_idx': 6,
#   'clip_start_sec': 251.7102,
#   'clip_end_sec': 267.77468,
#   'mIoU': 0.0,
#   'query': 'What sachet did I fold?'},
#  {'video_uid': 'a4728450-c05c-4d51-91e4-348f571d74bc',
#   'clip_uid': '3231822a-fc8b-4207-b0b8-5cbb1344cb2f',
#   'annotation_uid': 'e664889e-c822-4646-afdc-4150fadde398',
#   'query_idx': 7,
#   'clip_start_sec': 316.42368,
#   'clip_end_sec': 337.82368,
#   'mIoU': 0.0,
#   'query': 'where did I place my hand while cooking?'},
#  {'video_uid': '5802f3e8-c11e-4403-b6c4-7504257be73c',
#   'clip_uid': 'b810fff6-0df0-479a-b58c-012e42e4f7b3',
#   'annotation_uid': '91e86f79-bde0-4a07-bec6-9d7c3bb4aa82',
#   'query_idx': 6,
#   'clip_start_sec': 281.43285,
#   'clip_end_sec': 323.42196,
#   'mIoU': 0.07374696782682869,
#   'query': 'What machine did I blow?'},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': '58fa07ae-2992-4dc9-842a-e5a73ee3d345',
#   'annotation_uid': '1cf514d5-81b8-47b6-b378-d3efa5829592',
#   'query_idx': 0,
#   'clip_start_sec': 70.34414,
#   'clip_end_sec': 81.74455,
#   'mIoU': 0.035890179629629655,
#   'query': 'What object did I light'},
#  {'video_uid': '216c7a1a-7ec3-4aa0-a465-e37e7b5fd2f3',
#   'clip_uid': '093259bc-5b71-4204-be7b-5f7b5b5f20cb',
#   'annotation_uid': '5ecca0b5-c8b3-4e76-8332-712f83bf9b90',
#   'query_idx': 7,
#   'clip_start_sec': 895.78,
#   'clip_end_sec': 899.78,
#   'mIoU': 0.01422855219878635,
#   'query': 'where was the phone before I touched it'},
#  {'video_uid': 'd61475bb-fd97-43e3-8b7d-a242064a9d10',
#   'clip_uid': '1945d70d-bb9d-4523-aa31-7cfedb76b6c6',
#   'annotation_uid': 'b303aa34-c8e8-444e-a7f0-a850f3a8d178',
#   'query_idx': 0,
#   'clip_start_sec': 73.22931,
#   'clip_end_sec': 74.20862,
#   'mIoU': 0.0022464458781361963,
#   'query': 'Where was the container after I dropped it?'},
#  {'video_uid': 'd61475bb-fd97-43e3-8b7d-a242064a9d10',
#   'clip_uid': '7bf24899-4a05-46d4-b47d-36ce045643d8',
#   'annotation_uid': '6b7b963d-351a-4108-ad85-d33fcd5c304c',
#   'query_idx': 1,
#   'clip_start_sec': 14.89415,
#   'clip_end_sec': 16.18649,
#   'mIoU': 0.002029740350877192,
#   'query': 'What did I put on the table?'},
#  {'video_uid': '53da674a-089d-428a-a719-e322b2de002b',
#   'clip_uid': 'e4cf448f-e442-4e19-bf87-1eee8fbf59d8',
#   'annotation_uid': 'b4118c52-8258-4f95-8812-03bfd8fef42e',
#   'query_idx': 6,
#   'clip_start_sec': 351.81719,
#   'clip_end_sec': 358.61341,
#   'mIoU': 0.3264648546884923,
#   'query': 'How many oven tray did I put in the oven ? '},
#  {'video_uid': 'a330bb33-7cef-48d8-81e8-e0abd9fd0896',
#   'clip_uid': '611edaf1-8c1b-4093-b057-00e1e99ce1fc',
#   'annotation_uid': '5dd8ac88-ac29-4f5c-86ae-6b49edfc4eca',
#   'query_idx': 0,
#   'clip_start_sec': 0.0,
#   'clip_end_sec': 35.0,
#   'mIoU': 0.22812698772975376,
#   'query': 'who did I talk to at a rocky area?'},
#  {'video_uid': 'cd7c3bc6-24df-465c-9b63-a7961a7558de',
#   'clip_uid': 'c664f078-9b34-4a58-b949-180ac4bc0980',
#   'annotation_uid': '02755a4f-8f0c-46bf-a38f-780e3232752e',
#   'query_idx': 7,
#   'clip_start_sec': 156.67094,
#   'clip_end_sec': 158.64884,
#   'mIoU': 0.0,
#   'query': 'Where was the drilling machine before hitting the plank?\n'},
#  {'video_uid': '225a1ffe-3e7e-4ff8-a47e-2e80989077fe',
#   'clip_uid': '2c1724ce-f438-4d63-a699-8a7f65e3cbd9',
#   'annotation_uid': '41315e00-678a-435a-9a9b-a7316b8a40fd',
#   'query_idx': 6,
#   'clip_start_sec': 197.36281,
#   'clip_end_sec': 198.54994,
#   'mIoU': 0.06602339349137215,
#   'query': 'Where was the cloth before I picked it? '},
#  {'video_uid': 'fb7cc35d-3272-44a4-b8f2-15cd24fa345b',
#   'clip_uid': 'ab094ea2-9251-4f10-945b-c2ab00c5282e',
#   'annotation_uid': 'd2ba7cbc-d85e-43e2-8078-193aa9e99c24',
#   'query_idx': 3,
#   'clip_start_sec': 99.26734,
#   'clip_end_sec': 127.796,
#   'mIoU': 0.09505240610733183,
#   'query': 'What time did i chop the carrots?'},
#  {'video_uid': 'd88d4e54-5e5e-4c08-9a87-80958f9e4ec1',
#   'clip_uid': '0edc229a-eb4a-473c-b66b-550c19eecd42',
#   'annotation_uid': '96996e4f-02ed-4086-9712-377833ae29b2',
#   'query_idx': 7,
#   'clip_start_sec': 146.35499,
#   'clip_end_sec': 151.88186,
#   'mIoU': 0.05551399420950294,
#   'query': 'In what location did I see my black sneakers?'},
#  {'video_uid': '66a0900b-069d-48bf-9071-f4e659f8a9d0',
#   'clip_uid': 'cd7ccaeb-9d60-4aab-ab83-ea223004bad9',
#   'annotation_uid': 'aa303ded-59e2-46bc-81ed-a46d0a0413dd',
#   'query_idx': 0,
#   'clip_start_sec': 6.0,
#   'clip_end_sec': 7.0,
#   'mIoU': 0.03428571428571429,
#   'query': 'where was the nylon before I picked it up'},
#  {'video_uid': '243e800d-fc75-473d-b944-a95844e13a78',
#   'clip_uid': '8aadc754-fb37-4eae-ba7f-47949b5b3835',
#   'annotation_uid': '76cea951-4e11-4d38-af56-206713badd3a',
#   'query_idx': 2,
#   'clip_start_sec': 258.017,
#   'clip_end_sec': 261.0,
#   'mIoU': 0.01680263814616758,
#   'query': 'How many chair pillow are on the grey chair?'},
#  {'video_uid': '80f3dd0d-6ad9-4691-9de5-dc01a834bc0a',
#   'clip_uid': '2bbc6cdf-b662-498e-9a9f-231dd5ac2a9e',
#   'annotation_uid': 'efa7da94-3c84-48d3-a8cf-d9bc0ba377da',
#   'query_idx': 1,
#   'clip_start_sec': 7.332,
#   'clip_end_sec': 12.018,
#   'mIoU': 0.10593329318219824,
#   'query': 'Where was the phone before I operate it?'},
#  {'video_uid': '805989f6-0696-4de2-ad9b-0f194e0ac48d',
#   'clip_uid': 'eaf8d34a-0e20-45d0-a288-569df047461e',
#   'annotation_uid': '2ce0dc4d-d51a-4a07-93a1-fe0c3fdc3c78',
#   'query_idx': 1,
#   'clip_start_sec': 277.513,
#   'clip_end_sec': 282.013,
#   'mIoU': 0.008844038629899582,
#   'query': 'What did i put on the power drill'},
#  {'video_uid': '4d89d233-dbcf-4ea2-a90f-9a2c3b42d1d5',
#   'clip_uid': '3d688dd9-8a21-43bd-9d1b-9be73b0b26bb',
#   'annotation_uid': 'fa6199c4-090e-437f-b7fe-6cfb158cacb3',
#   'query_idx': 1,
#   'clip_start_sec': 452.05372,
#   'clip_end_sec': 453.6149,
#   'mIoU': 0.0006661034666666577,
#   'query': 'In what Location did I last see the small plastic chair?'},
#  {'video_uid': '8e748fd1-e30e-4bf6-a04f-5f570ca075ac',
#   'clip_uid': 'a325ce85-cae5-4faa-99bb-7272918fcf19',
#   'annotation_uid': 'e7aae1c9-3c56-4f63-81ad-bd55fe122448',
#   'query_idx': 2,
#   'clip_start_sec': 403.3868,
#   'clip_end_sec': 408.57537,
#   'mIoU': 0.31805362259929,
#   'query': 'When did I talk to the cashier at the store'},
#  {'video_uid': '80f3dd0d-6ad9-4691-9de5-dc01a834bc0a',
#   'clip_uid': '2bbc6cdf-b662-498e-9a9f-231dd5ac2a9e',
#   'annotation_uid': 'efa7da94-3c84-48d3-a8cf-d9bc0ba377da',
#   'query_idx': 3,
#   'clip_start_sec': 166.366,
#   'clip_end_sec': 170.366,
#   'mIoU': 0.37162710321346565,
#   'query': 'What beverage did I drink? '},
#  {'video_uid': '356dd07e-8165-494c-9be8-b82d314bf88d',
#   'clip_uid': 'ba5b8b24-2335-40c0-86c9-bfd76620e1fa',
#   'annotation_uid': 'ee530e0f-5a2e-469c-b089-a666aea6aeb2',
#   'query_idx': 2,
#   'clip_start_sec': 409.93459,
#   'clip_end_sec': 418.51348,
#   'mIoU': 0.0015001337704918035,
#   'query': 'What color is the packet I lifted. '},
#  {'video_uid': '50d413f2-5709-475d-8999-6135dcd7d63f',
#   'clip_uid': 'c8f4c698-167f-44f8-b624-3fb69660a7ce',
#   'annotation_uid': '99d4a11a-192a-474b-8af7-b1155fb0e9fa',
#   'query_idx': 3,
#   'clip_start_sec': 359.0,
#   'clip_end_sec': 360.0,
#   'mIoU': 0.03151515151515151,
#   'query': 'where was the grey soldering gun before I picked it?'},
#  {'video_uid': '59f00ff2-4e01-4498-ab40-4713217686bc',
#   'clip_uid': 'e2171ff4-e32e-437f-9792-f37613e86598',
#   'annotation_uid': '6a1bcd20-6a17-41a4-8c20-68b2c9d8f42d',
#   'query_idx': 3,
#   'clip_start_sec': 238.773,
#   'clip_end_sec': 241.773,
#   'mIoU': 0.0076924766319762345,
#   'query': 'how many nails?'},
#  {'video_uid': 'a94b8e4a-8921-4dcb-a79b-2c079e299e3a',
#   'clip_uid': '4a37144f-63cd-4729-809c-f05ec1839036',
#   'annotation_uid': '55fd815b-7ba3-4ba8-ba30-ad97d073beec',
#   'query_idx': 3,
#   'clip_start_sec': 19.34333,
#   'clip_end_sec': 20.0,
#   'mIoU': 0.00022333898373983683,
#   'query': 'where was the sandals?'},
#  {'video_uid': '18a3840b-7463-43c4-9aa9-b1d8e486fa84',
#   'clip_uid': '4ecd1707-cce9-46bf-9846-11d031f79556',
#   'annotation_uid': '5f18498a-1243-4d03-a59e-cbe60c06e9ab',
#   'query_idx': 0,
#   'clip_start_sec': 30.0,
#   'clip_end_sec': 31.0,
#   'mIoU': 0.0,
#   'query': 'Where was the tape measure?'},
#  {'video_uid': 'b68709fe-2a73-49c3-a468-afcf56ab234c',
#   'clip_uid': '9093c341-5f95-4402-a2dd-6a84aa42bf1f',
#   'annotation_uid': '3c52dcc8-31e1-4a6a-b28e-f0dc30a800e9',
#   'query_idx': 6,
#   'clip_start_sec': 358.70621,
#   'clip_end_sec': 359.24082,
#   'mIoU': 0.0005197597222222092,
#   'query': 'Where is the scrapper?'},
#  {'video_uid': 'c864505c-9d49-4da4-bf7e-254b4c348c03',
#   'clip_uid': '89f7ac43-956d-4d7e-b8a1-442ecff20ad6',
#   'annotation_uid': '05947447-1e02-47ad-9209-26a868968bef',
#   'query_idx': 4,
#   'clip_start_sec': 243.46158,
#   'clip_end_sec': 243.46158,
#   'mIoU': 0.005720642302188416,
#   'query': 'What did I put in the steel bowl?'},
#  {'video_uid': '9bf859f2-62ff-4f2e-9eb8-ef69feb4d343',
#   'clip_uid': 'ca304360-2402-4241-a6eb-5ff2f300546f',
#   'annotation_uid': '994f38c0-b2b8-4677-8bb1-10955188c558',
#   'query_idx': 5,
#   'clip_start_sec': 287.0,
#   'clip_end_sec': 296.0,
#   'mIoU': 0.008901829106191587,
#   'query': 'how many books were in the container?'},
#  {'video_uid': '50d413f2-5709-475d-8999-6135dcd7d63f',
#   'clip_uid': 'c8f4c698-167f-44f8-b624-3fb69660a7ce',
#   'annotation_uid': '99d4a11a-192a-474b-8af7-b1155fb0e9fa',
#   'query_idx': 4,
#   'clip_start_sec': 409.0,
#   'clip_end_sec': 411.0,
#   'mIoU': 0.008053181386514719,
#   'query': 'Where was the wrench before I picked it?'},
#  {'video_uid': 'cd7c3bc6-24df-465c-9b63-a7961a7558de',
#   'clip_uid': 'c664f078-9b34-4a58-b949-180ac4bc0980',
#   'annotation_uid': '02755a4f-8f0c-46bf-a38f-780e3232752e',
#   'query_idx': 6,
#   'clip_start_sec': 469.8856,
#   'clip_end_sec': 470.93117,
#   'mIoU': 0.0,
#   'query': 'In what location did I see the toolbox?'},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': 'f748feb9-9a15-4f2b-9b65-186f90107c7c',
#   'annotation_uid': 'd167c9f6-d252-40a8-b876-650ee2f6b1a5',
#   'query_idx': 7,
#   'clip_start_sec': 528.85236,
#   'clip_end_sec': 534.2977,
#   'mIoU': 0.0013666735686274478,
#   'query': 'In what room did i leave dough mixer?'},
#  {'video_uid': '935f591f-9184-4ea8-869a-4c56d7029aa4',
#   'clip_uid': '90602dc0-4c33-4b26-b4d5-c63105c40187',
#   'annotation_uid': 'c6a76e69-c3c3-41d2-aa72-ccbc231fb56a',
#   'query_idx': 1,
#   'clip_start_sec': 468.86195,
#   'clip_end_sec': 480.067,
#   'mIoU': 0.002204431221539882,
#   'query': 'In what  location did I see the red sack?'},
#  {'video_uid': '18a3840b-7463-43c4-9aa9-b1d8e486fa84',
#   'clip_uid': '8a855547-3574-4e67-a7ac-41b072984e3b',
#   'annotation_uid': '1918d43a-17fc-43d8-bfac-13bbd6dd3356',
#   'query_idx': 1,
#   'clip_start_sec': 38.92941,
#   'clip_end_sec': 44.49678,
#   'mIoU': 0.0,
#   'query': 'Where did I insert the blue wire?'},
#  {'video_uid': '30b9ff64-51c8-4481-ba6a-733ea2060aef',
#   'clip_uid': '1731de62-b1b9-4b84-bd55-412cd67e9b3c',
#   'annotation_uid': '058aa522-a4a2-4330-89c8-4d6091621de9',
#   'query_idx': 3,
#   'clip_start_sec': 62.33302,
#   'clip_end_sec': 69.128,
#   'mIoU': 0.0,
#   'query': 'Who did I talk to in the house?'},
#  {'video_uid': '53da674a-089d-428a-a719-e322b2de002b',
#   'clip_uid': '9ab5fd9f-77e4-4438-a546-a4b6ed889f1a',
#   'annotation_uid': '0139f386-6dc6-4aad-a150-dc6745338445',
#   'query_idx': 1,
#   'clip_start_sec': 78.79924,
#   'clip_end_sec': 110.0526,
#   'mIoU': 0.7193059977419816,
#   'query': 'What did I put in the dough? '},
#  {'video_uid': 'b3ba6f28-2506-4121-ad08-c5b96b410a1f',
#   'clip_uid': '28c1f367-b80b-4072-a54c-fa17b207bf7b',
#   'annotation_uid': '12525c2c-1f9d-41ce-86fc-35942d49645e',
#   'query_idx': 2,
#   'clip_start_sec': 152.34253,
#   'clip_end_sec': 160.54564,
#   'mIoU': 0.010667178960116373,
#   'query': 'What wood did I hit with the claw tool?'},
#  {'video_uid': 'adf65602-f5ee-456a-a098-db19a521ce38',
#   'clip_uid': 'a185abe1-ae2e-4ab4-aa5c-d2f45abfd7c9',
#   'annotation_uid': '043c0c21-82d5-4f6d-8971-4aff968143ee',
#   'query_idx': 3,
#   'clip_start_sec': 175.43704,
#   'clip_end_sec': 175.43704,
#   'mIoU': 0.5514652763835325,
#   'query': 'how many are the boxes'},
#  {'video_uid': 'b68709fe-2a73-49c3-a468-afcf56ab234c',
#   'clip_uid': '956488d0-1b28-41b5-a13f-7f1b72e1c2c7',
#   'annotation_uid': 'bd742c40-e95d-46ba-83aa-da36dac6720c',
#   'query_idx': 2,
#   'clip_start_sec': 114.66639,
#   'clip_end_sec': 114.66639,
#   'mIoU': 0.013333333333333332,
#   'query': 'what color was the bucket?'},
#  {'video_uid': 'b68709fe-2a73-49c3-a468-afcf56ab234c',
#   'clip_uid': '956488d0-1b28-41b5-a13f-7f1b72e1c2c7',
#   'annotation_uid': 'bd742c40-e95d-46ba-83aa-da36dac6720c',
#   'query_idx': 0,
#   'clip_start_sec': 1.533,
#   'clip_end_sec': 3.53331,
#   'mIoU': 0.16405150113945582,
#   'query': 'where was the mud balance before i picked it?'},
#  {'video_uid': 'df0b81a6-826c-4e9b-8921-392304716c0e',
#   'clip_uid': 'eeca9b8b-d737-4a70-ad68-0cb49cf36a67',
#   'annotation_uid': '67307fe6-bb9a-48b4-a4f0-0c76ebc28f11',
#   'query_idx': 0,
#   'clip_start_sec': 0.0,
#   'clip_end_sec': 2.70572,
#   'mIoU': 0.0,
#   'query': 'What color is the tool box on the cabinet?'},
#  {'video_uid': '2ac65951-49b0-4629-981e-edc34b8cdb0f',
#   'clip_uid': '085f7a8b-e1e5-4e7b-a83d-5ea650edd9fe',
#   'annotation_uid': 'eacfb70a-8ac0-4ecc-a1da-a0030ec93ced',
#   'query_idx': 3,
#   'clip_start_sec': 8.20129,
#   'clip_end_sec': 11.13013,
#   'mIoU': 0.0,
#   'query': 'Where was the dog before I picked the leash?'},
#  {'video_uid': 'e636dd8b-7682-4910-8b26-781f192c37ec',
#   'clip_uid': '31e2ad5b-2566-4542-b18c-59febac66740',
#   'annotation_uid': '49000905-f450-46ea-9811-1f9d80ccec84',
#   'query_idx': 7,
#   'clip_start_sec': 151.60913,
#   'clip_end_sec': 155.428,
#   'mIoU': 0.0,
#   'query': 'Where were the cloths before I picked them?'},
#  {'video_uid': '2d442f12-3595-4b2d-b8c5-583b65c0c49f',
#   'clip_uid': 'f32cb53d-4a80-499c-bb32-cefef3abe205',
#   'annotation_uid': 'c46d08ce-3b1d-4071-9c86-1d37ecf7ef13',
#   'query_idx': 1,
#   'clip_start_sec': 87.86366,
#   'clip_end_sec': 91.958,
#   'mIoU': 0.005213899851612906,
#   'query': 'In what location did I see the cat?'},
#  {'video_uid': 'ae2dfec4-6094-4ff3-a404-a8a6ab1e0f02',
#   'clip_uid': '245f3b76-ef46-48d1-b37c-afe73efbf1cf',
#   'annotation_uid': '012e4b4f-2304-4304-8546-d185c919caa5',
#   'query_idx': 5,
#   'clip_start_sec': 320.16684,
#   'clip_end_sec': 321.07857,
#   'mIoU': 0.0005065166666666857,
#   'query': 'Where was the drill machine?'},
#  {'video_uid': 'b884e44c-07d8-426e-8356-1be4905c2675',
#   'clip_uid': '6b9efa86-2580-465b-89b9-877dbd18467c',
#   'annotation_uid': '216012cf-8bde-4fb0-9314-5fc237199030',
#   'query_idx': 0,
#   'clip_start_sec': 5.34941,
#   'clip_end_sec': 7.0,
#   'mIoU': 0.0,
#   'query': 'What size was the black box?'},
#  {'video_uid': 'c40736ec-e68f-43f6-960d-7d8bd467b1c7',
#   'clip_uid': '89193dbc-0ffa-4ee2-9ea8-c434ce177310',
#   'annotation_uid': '294d2807-8bdd-4267-a4f1-a0ce18ff7969',
#   'query_idx': 1,
#   'clip_start_sec': 105.85125,
#   'clip_end_sec': 108.58912,
#   'mIoU': 0.0027947000244200253,
#   'query': 'Where is the scissors?'},
#  {'video_uid': '9930414f-b998-4217-b6b5-aa686236fdf8',
#   'clip_uid': 'c7873f07-7b9c-4794-9a56-fdebeeceee68',
#   'annotation_uid': '1a8ce90c-2273-495a-9366-52345df0f7d1',
#   'query_idx': 7,
#   'clip_start_sec': 205.02932,
#   'clip_end_sec': 216.624,
#   'mIoU': 0.04038545569482569,
#   'query': 'Where is the cream bag?'},
#  {'video_uid': '2763dbfc-8488-4264-b31f-4b12096c4c4b',
#   'clip_uid': 'b1bd830a-a738-4ebe-9e88-c348def0de90',
#   'annotation_uid': '8d9613f4-caa1-4aec-8461-0eaeb31bc896',
#   'query_idx': 0,
#   'clip_start_sec': 27.12207,
#   'clip_end_sec': 28.41673,
#   'mIoU': 0.0,
#   'query': 'In what location did I see the empty orange keg?'},
#  {'video_uid': '7c5eb718-99b2-48ac-bb1c-ef0158a6361b',
#   'clip_uid': '61a0bd1c-c14b-41bb-a97e-05cd58207e5a',
#   'annotation_uid': 'a0169aab-73df-4e20-ba53-2f3247115275',
#   'query_idx': 6,
#   'clip_start_sec': 424.6101,
#   'clip_end_sec': 480.034,
#   'mIoU': 0.02307749034443394,
#   'query': 'Where was the blue plank?'},
#  {'video_uid': '7b3bea48-bd62-46b7-888d-2cc6e4bbd11b',
#   'clip_uid': '992cee60-a8af-423f-8a40-5b14208fcc1a',
#   'annotation_uid': '1ec79f94-bc66-4a6f-8a25-29d5c639f15f',
#   'query_idx': 0,
#   'clip_start_sec': 0.0,
#   'clip_end_sec': 79.64063,
#   'mIoU': 0.041642159477124185,
#   'query': 'Where is the wooden tray?'},
#  {'video_uid': '3fc60e72-91ad-4320-bd07-1cf753f4a5f1',
#   'clip_uid': '740a9d13-cf77-4e7d-91b5-a3ebf6d270ec',
#   'annotation_uid': 'ba973d7d-473e-4df9-955b-d590cd9436f8',
#   'query_idx': 2,
#   'clip_start_sec': 353.90828,
#   'clip_end_sec': 361.114,
#   'mIoU': 0.013420264174930053,
#   'query': 'In what location did I see the parked car?'},
#  {'video_uid': '363b5839-a7c3-4c2e-b966-9530e38045a1',
#   'clip_uid': '2b19ee03-d94f-4c1f-822d-d4c00a2066cc',
#   'annotation_uid': '6cbdae98-52c7-4551-9173-851d5e828812',
#   'query_idx': 5,
#   'clip_start_sec': 247.7484,
#   'clip_end_sec': 256.0,
#   'mIoU': 0.0,
#   'query': 'where is the toolbox?'},
#  {'video_uid': '3534864b-2289-4aaf-b3ed-10eeeee7acd2',
#   'clip_uid': 'bccc3bde-d9b2-4edb-9b1f-a3f42dd07b3e',
#   'annotation_uid': 'f8fc39c5-c320-46f3-95f9-33b6e3c712ea',
#   'query_idx': 0,
#   'clip_start_sec': 100.35182,
#   'clip_end_sec': 102.60116,
#   'mIoU': 0.00495092825396823,
#   'query': 'How many dough cutters did I pick?'},
#  {'video_uid': '3534864b-2289-4aaf-b3ed-10eeeee7acd2',
#   'clip_uid': '8acaf6f6-5396-4df6-98e6-13baea8f8af8',
#   'annotation_uid': '58195979-ad36-4b82-9d26-be59455e1d4d',
#   'query_idx': 6,
#   'clip_start_sec': 390.71503,
#   'clip_end_sec': 392.53518,
#   'mIoU': 0.000373530116338862,
#   'query': 'How many jugs of water did I pour into the mixer?'},
#  {'video_uid': '363b5839-a7c3-4c2e-b966-9530e38045a1',
#   'clip_uid': '2b19ee03-d94f-4c1f-822d-d4c00a2066cc',
#   'annotation_uid': '3c445280-f531-44d0-8581-7c9248092f53',
#   'query_idx': 1,
#   'clip_start_sec': 159.08509,
#   'clip_end_sec': 159.76209,
#   'mIoU': 0.0007522222222222138,
#   'query': 'Where did I put the folding rule?'},
#  {'video_uid': '3534864b-2289-4aaf-b3ed-10eeeee7acd2',
#   'clip_uid': '8acaf6f6-5396-4df6-98e6-13baea8f8af8',
#   'annotation_uid': '37fabd23-dbd9-4a7d-9f33-d6507eb0fd76',
#   'query_idx': 16,
#   'clip_start_sec': 747.40772,
#   'clip_end_sec': 749.0,
#   'mIoU': 0.0008289951332244034,
#   'query': 'What flour bag did i fold?'},
#  {'video_uid': '7d6d6cae-0601-485d-b900-482b4254e9f8',
#   'clip_uid': '5bff21b4-ac93-450f-a189-b2fb7cff4d99',
#   'annotation_uid': '1414e946-774f-4d94-99e3-8b72d2bfe930',
#   'query_idx': 7,
#   'clip_start_sec': 442.0,
#   'clip_end_sec': 475.0,
#   'mIoU': 0.0,
#   'query': 'Where was the hair brush?'},
#  {'video_uid': '7d6d6cae-0601-485d-b900-482b4254e9f8',
#   'clip_uid': '522b72ce-f947-4cdb-8ebb-ebdfdbe6f04f',
#   'annotation_uid': 'b4c56cdf-bfc9-4a6c-a57e-8c5fa417f401',
#   'query_idx': 6,
#   'clip_start_sec': 435.25698,
#   'clip_end_sec': 444.684,
#   'mIoU': 0.021417052646703027,
#   'query': 'In what location did I last see the napkin I used in cleaning my hands?'},
#  {'video_uid': '819257df-e650-4ed6-9c0b-26bd8e2ac726',
#   'clip_uid': '1bae2411-3eb4-4aa7-bdb5-c8634329d512',
#   'annotation_uid': 'bb51a1f5-be3c-4e42-be20-a667f53fde86',
#   'query_idx': 3,
#   'clip_start_sec': 402.62673,
#   'clip_end_sec': 405.0,
#   'mIoU': 0.0,
#   'query': 'Where was the knitted cape?'},
#  {'video_uid': 'c864505c-9d49-4da4-bf7e-254b4c348c03',
# ...
#   'query_idx': 5,
#   'clip_start_sec': 435.2079,
#   'clip_end_sec': 437.58563,
#   'mIoU': 0.0,
#   'query': 'What color of container did I pick from the ground?'},
#  {'video_uid': 'fec1f883-fc5c-4257-985e-26efaec68ddc',
#   'clip_uid': '53c86be4-190d-4410-8750-179a7edc70b3',
#   'annotation_uid': '6e530270-92ce-4518-b45a-94fe5aabf02f',
#   'query_idx': 4,
#   'clip_start_sec': 290.28542,
#   'clip_end_sec': 297.00418,
#   'mIoU': 0.0,
#   'query': 'How many dustbins were in the corridor?'},
#  {'video_uid': '18e84829-901a-414d-8a2b-d1d2b3244db7',
#   'clip_uid': 'f4c804be-6a83-4f29-9e45-81bf6a2b00cb',
#   'annotation_uid': '35703a64-29d5-4bd1-876c-2926cf1b7418',
#   'query_idx': 1,
#   'clip_start_sec': 68.79329,
#   'clip_end_sec': 71.0,
#   'mIoU': 0.1597764205197486,
#   'query': 'Where was the box?'},
#  {'video_uid': '824e7896-904a-4ff5-b7ee-e21df21918c2',
#   'clip_uid': 'e8842ef9-1d09-4393-ba98-ad18800c6f3e',
#   'annotation_uid': 'fd3c3693-1eef-4b96-bb4a-72361856b371',
#   'query_idx': 0,
#   'clip_start_sec': 187.28235,
#   'clip_end_sec': 190.87526,
#   'mIoU': 0.0,
#   'query': 'What color is the guitar?'},
#  {'video_uid': 'a4728450-c05c-4d51-91e4-348f571d74bc',
#   'clip_uid': '3231822a-fc8b-4207-b0b8-5cbb1344cb2f',
#   'annotation_uid': 'a89efc9c-f6bb-472a-a8c6-bdae52f82638',
#   'query_idx': 0,
#   'clip_start_sec': 8.97254,
#   'clip_end_sec': 17.51162,
#   'mIoU': 0.5362022554305378,
#   'query': 'What kitchen tool did I cut the springer onions with?'},
#  {'video_uid': 'df0b81a6-826c-4e9b-8921-392304716c0e',
#   'clip_uid': 'eeca9b8b-d737-4a70-ad68-0cb49cf36a67',
#   'annotation_uid': '67307fe6-bb9a-48b4-a4f0-0c76ebc28f11',
#   'query_idx': 6,
#   'clip_start_sec': 207.41635,
#   'clip_end_sec': 210.037,
#   'mIoU': 0.0,
#   'query': 'Where is the power tool?'},
#  {'video_uid': 'bd3a319e-0573-4802-a6d1-6d89910098e8',
#   'clip_uid': 'a35ac9e4-bb20-460e-9c9d-67806ab9d13f',
#   'annotation_uid': 'e93f1e16-136d-4e25-8b89-1fa3d6c2b74e',
#   'query_idx': 4,
#   'clip_start_sec': 79.0,
#   'clip_end_sec': 85.4,
#   'mIoU': 0.40038920831490515,
#   'query': 'How many bottles of coke was in the pack I took?'},
#  {'video_uid': '9c50dcc2-f3af-4529-afce-fec005c78a39',
#   'clip_uid': '4ab42038-79a6-433c-905d-f1426561b9f8',
#   'annotation_uid': 'a1c3bef5-3b62-4d78-962b-71564cc2e946',
#   'query_idx': 2,
#   'clip_start_sec': 83.34764,
#   'clip_end_sec': 87.42505,
#   'mIoU': 0.052553284444444445,
#   'query': 'Where did I put the boots?'},
#  {'video_uid': 'd526d862-080f-4b3e-9894-6ff997f5d6ac',
#   'clip_uid': 'b69e6150-0309-4202-bf4a-9a342f80d6d7',
#   'annotation_uid': 'cfa46eb6-259c-4591-8e1e-0c748dd68bad',
#   'query_idx': 2,
#   'clip_start_sec': 36.14568,
#   'clip_end_sec': 39.94075,
#   'mIoU': 0.01124465185185186,
#   'query': 'What color is the air fryer?'},
#  {'video_uid': '18a3840b-7463-43c4-9aa9-b1d8e486fa84',
#   'clip_uid': 'c0a634a9-3dbe-44f8-9a04-7718d2a2762e',
#   'annotation_uid': 'd5ca0729-597f-4d3b-9aa0-3fae2015c997',
#   'query_idx': 2,
#   'clip_start_sec': 68.21018,
#   'clip_end_sec': 89.01975,
#   'mIoU': 0.03769580251826814,
#   'query': 'Where did I carry the table to'},
#  {'video_uid': '8a6a3316-d682-4a76-81db-b244081765c9',
#   'clip_uid': 'e776ca99-4a92-4444-8a1f-fa55bfa381e0',
#   'annotation_uid': '0f7085e5-1816-4599-83d7-c04189b1218f',
#   'query_idx': 6,
#   'clip_start_sec': 366.60256,
#   'clip_end_sec': 370.76756,
#   'mIoU': 0.006112534378437874,
#   'query': 'How many sandy patches were on the field?'},
#  {'video_uid': '53da674a-089d-428a-a719-e322b2de002b',
#   'clip_uid': '59c01c97-9312-47f8-b911-dd789978714b',
#   'annotation_uid': '7f82729b-db06-4e3e-8a4f-2e345a7366b6',
#   'query_idx': 2,
#   'clip_start_sec': 108.86039,
#   'clip_end_sec': 137.889,
#   'mIoU': 0.6075007522615816,
#   'query': 'How many trays of pastries did I take from the oven?'},
#  {'video_uid': '182dffe9-d2bf-4a7d-b1d8-137470f0143d',
#   'clip_uid': 'ee379d11-2535-4300-9d9e-dc9d9c53d94f',
#   'annotation_uid': '73417dbc-f91c-4cb3-bd0f-9101babef11c',
#   'query_idx': 4,
#   'clip_start_sec': 470.26718,
#   'clip_end_sec': 473.0,
#   'mIoU': 0.0011399415824314496,
#   'query': 'Where did I put the lid?'},
#  {'video_uid': '73773748-14ac-40ba-9ef8-d5a70865aeea',
#   'clip_uid': 'f2f4fd65-681a-41ab-b6cf-c7feb025a040',
#   'annotation_uid': '88f6d6d0-a58a-45b9-8a9e-c342acc1722d',
#   'query_idx': 4,
#   'clip_start_sec': 275.5428,
#   'clip_end_sec': 283.57731,
#   'mIoU': 0.15782500476041053,
#   'query': 'In what room did I bring out cassette from a drawer?'},
#  {'video_uid': 'adf65602-f5ee-456a-a098-db19a521ce38',
#   'clip_uid': 'a185abe1-ae2e-4ab4-aa5c-d2f45abfd7c9',
#   'annotation_uid': '043c0c21-82d5-4f6d-8971-4aff968143ee',
#   'query_idx': 1,
#   'clip_start_sec': 89.34805,
#   'clip_end_sec': 89.34805,
#   'mIoU': 0.0,
#   'query': 'what color is the towel'},
#  {'video_uid': '9f28e782-417c-4c8b-a7ae-42fc96a0e94f',
#   'clip_uid': 'd7b8f461-db42-4365-9f89-83f923528293',
#   'annotation_uid': 'fa5f4111-651a-495e-b006-d5be045b4091',
#   'query_idx': 7,
#   'clip_start_sec': 446.42212,
#   'clip_end_sec': 467.30328,
#   'mIoU': 0.0,
#   'query': 'How many tomatoes did I chop?'},
#  {'video_uid': 'eb81442c-a322-49ea-b243-a39d2e288b9b',
#   'clip_uid': '3f268027-765d-4988-91d9-f0f948e6f9bc',
#   'annotation_uid': '3fd7062b-6dd8-4d73-a659-9d6a22353155',
#   'query_idx': 3,
#   'clip_start_sec': 409.62122,
#   'clip_end_sec': 480.067,
#   'mIoU': 0.03322767863652366,
#   'query': 'What color was the tarpaulin  I last spread over the tent?'},
#  {'video_uid': '18a3840b-7463-43c4-9aa9-b1d8e486fa84',
#   'clip_uid': '8a855547-3574-4e67-a7ac-41b072984e3b',
#   'annotation_uid': 'ba9a6987-2517-47b3-8928-fecb9d538dc4',
#   'query_idx': 5,
#   'clip_start_sec': 214.94763,
#   'clip_end_sec': 218.947,
#   'mIoU': 0.0,
#   'query': 'Where did I put the ceiling cornice?'},
#  {'video_uid': '404cc1c1-f7a0-4e16-9a39-b8e2d5d9ae59',
#   'clip_uid': '1c597fc1-7bd0-4325-abbc-645e3ec71866',
#   'annotation_uid': '5f5ccaa6-6b65-4f5c-b2f3-57d5ad659fc1',
#   'query_idx': 0,
#   'clip_start_sec': 9.58492,
#   'clip_end_sec': 14.30371,
#   'mIoU': 0.07031326376811595,
#   'query': 'Where did I put the nylon bag?'},
#  {'video_uid': '04994ce8-9d47-44d6-a7b0-42b395e69390',
#   'clip_uid': 'a18c5454-8d7f-4380-944a-21854635d7f9',
#   'annotation_uid': '2e99957a-639e-44ff-a557-932cd806f88b',
#   'query_idx': 5,
#   'clip_start_sec': 249.97277,
#   'clip_end_sec': 262.0,
#   'mIoU': 0.006063911949485946,
#   'query': 'Where did I put tile cutter?'},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': 'f748feb9-9a15-4f2b-9b65-186f90107c7c',
#   'annotation_uid': 'ed904e38-6e0e-4e4e-9bfe-d4b28127fde4',
#   'query_idx': 11,
#   'clip_start_sec': 1094.50172,
#   'clip_end_sec': 1095.45814,
#   'mIoU': 0.0,
#   'query': 'In what room did i see the broom ?'},
#  {'video_uid': '2d29b45a-169b-453f-8050-98ec147b0ccf',
#   'clip_uid': 'a769264b-e62e-4515-be98-a5828a533e45',
#   'annotation_uid': '981741ad-4934-43a6-8517-29766b4b5049',
#   'query_idx': 1,
#   'clip_start_sec': 21.39145,
#   'clip_end_sec': 22.097,
#   'mIoU': 0.0,
#   'query': 'Where were the hammer before I picked it up?'},
#  {'video_uid': '624a6c0a-a4cb-4073-b501-48e4b6b679e4',
#   'clip_uid': '903e0bf6-db7e-4b1c-8cb9-867317963fde',
#   'annotation_uid': 'de967307-36f6-4906-8fcf-704fe39da1e7',
#   'query_idx': 1,
#   'clip_start_sec': 230.81,
#   'clip_end_sec': 243.81,
#   'mIoU': 0.011662912912912913,
#   'query': 'Who was with me when I repaired the engine?'},
#  {'video_uid': '516c9abc-dbf3-4f87-b78e-db0ab9d657ea',
#   'clip_uid': '86c3b190-a57a-4b88-a3be-4d8d47c8d867',
#   'annotation_uid': 'ccd6ec61-d38f-47b2-aae8-95e1f96de032',
#   'query_idx': 4,
#   'clip_start_sec': 202.83455,
#   'clip_end_sec': 207.32256,
#   'mIoU': 0.0,
#   'query': 'What color is the rag that I washed?'},
#  {'video_uid': '603ecf93-d2c1-4611-a690-76afd18935c8',
#   'clip_uid': 'cf1470f1-9a03-4944-95dd-7f8410bb6cc8',
#   'annotation_uid': '5466f293-f137-4272-806f-61ad284eb5f9',
#   'query_idx': 17,
#   'clip_start_sec': 945.37875,
#   'clip_end_sec': 947.72783,
#   'mIoU': 0.0,
#   'query': 'In what area did I leave the basin?'},
#  {'video_uid': '477feff8-a1ff-4f43-b726-273ca0fa47e9',
#   'clip_uid': '61de3e3f-8862-4d68-ab4a-2a26e81916d1',
#   'annotation_uid': '0d83a02d-0ed0-439a-98b6-5b9d479f8880',
#   'query_idx': 2,
#   'clip_start_sec': 65.7271,
#   'clip_end_sec': 67.0,
#   'mIoU': 0.05663624713324973,
#   'query': 'what color was the towel?'},
#  {'video_uid': '3ee7070a-fe81-49a9-97a2-902268af9985',
#   'clip_uid': 'a40dce18-488d-4acc-b754-fcd56c204db1',
#   'annotation_uid': '69ff5b62-0df3-4a8f-aa16-e224d4aa549e',
#   'query_idx': 0,
#   'clip_start_sec': 317.0,
#   'clip_end_sec': 341.0,
#   'mIoU': 0.0,
#   'query': 'Where did I put the remaining onions?'},
#  {'video_uid': 'd61475bb-fd97-43e3-8b7d-a242064a9d10',
#   'clip_uid': '534d9bf8-bdc5-4236-8dba-dd7b894218d2',
#   'annotation_uid': '9dafc673-3cd8-453d-ade5-b86cbf0a9df4',
#   'query_idx': 3,
#   'clip_start_sec': 397.85133,
#   'clip_end_sec': 398.95691,
#   'mIoU': 0.0,
#   'query': 'What card did I pick?'},
#  {'video_uid': '4dc58b9f-75f4-4f27-aa19-2b8ebd1daad6',
#   'clip_uid': 'e4dd3b6b-7801-4a19-bb66-9a0d8721f387',
#   'annotation_uid': '98fe7e4c-e1d1-46a8-be59-296dc81b872d',
#   'query_idx': 2,
#   'clip_start_sec': 413.90219,
#   'clip_end_sec': 415.902,
#   'mIoU': 0.012288955895061533,
#   'query': 'Where is the  orange cable?'},
#  {'video_uid': '5d090853-467e-4f95-9f9e-ac0582023111',
#   'clip_uid': '95daa74b-1edf-4f33-96ff-e0c7eb0c0dbb',
#   'annotation_uid': 'da1cb157-f680-480c-b1ee-680ab5de3c78',
#   'query_idx': 1,
#   'clip_start_sec': 270.445,
#   'clip_end_sec': 273.445,
#   'mIoU': 0.00125,
#   'query': 'In what location did I see frame?'},
#  {'video_uid': '86343e9e-b932-41d3-ad6f-83f2c2fe5486',
#   'clip_uid': '4ba774a8-cd2a-4889-9971-cc91f5c1afd4',
#   'annotation_uid': '45b0646b-3e1f-4e48-b295-d7de15701c52',
#   'query_idx': 1,
#   'clip_start_sec': 167.27719,
#   'clip_end_sec': 173.6,
#   'mIoU': 0.008174946262626267,
#   'query': 'What did I put in the bowl?'},
#  {'video_uid': 'a743a90e-f46c-4e55-a94d-a7f11c771207',
#   'clip_uid': '751201ad-5397-4956-a4f2-d73fb969b6c5',
#   'annotation_uid': '685813b4-c725-4e13-9c08-05abbccb7eab',
#   'query_idx': 4,
#   'clip_start_sec': 352.75895,
#   'clip_end_sec': 352.75895,
#   'mIoU': 0.2173996250692572,
#   'query': 'Where was mobile phone before i picked it?'},
#  {'video_uid': '8a6a3316-d682-4a76-81db-b244081765c9',
#   'clip_uid': 'e776ca99-4a92-4444-8a1f-fa55bfa381e0',
#   'annotation_uid': 'a2508f63-21cd-4bd6-8b94-dba2d71745c8',
#   'query_idx': 0,
#   'clip_start_sec': 97.84858,
#   'clip_end_sec': 103.0,
#   'mIoU': 0.0021633259842519692,
#   'query': 'who was I with when I first boarded the golf cart'},
#  {'video_uid': 'c0f702e1-d2e3-4277-8981-7177d106174a',
#   'clip_uid': '8bf16989-e870-44bb-863c-c6745e69f6fb',
#   'annotation_uid': '2ccb1927-953d-422a-9765-cb7f6db4ca5c',
#   'query_idx': 7,
#   'clip_start_sec': 185.16182,
#   'clip_end_sec': 190.591,
#   'mIoU': 0.0024536100865203436,
#   'query': 'Where was the stainless cup?'},
#  {'video_uid': '824e7896-904a-4ff5-b7ee-e21df21918c2',
#   'clip_uid': 'da0092ba-0247-4438-9172-4f60f00be608',
#   'annotation_uid': 'f5a0f3fe-dfd0-4b08-b913-79b55841b56b',
#   'query_idx': 5,
#   'clip_start_sec': 229.61754,
#   'clip_end_sec': 232.92673,
#   'mIoU': 0.28671066879284685,
#   'query': 'Where is the orange waste bin?'},
#  {'video_uid': 'e0c4d2c7-fd50-4c50-b40e-e1eda4a5708b',
#   'clip_uid': 'aa2afb03-41d8-42fc-a111-982d9319f1c4',
#   'annotation_uid': '3a023968-376e-4f92-a218-be14db8de55c',
#   'query_idx': 0,
#   'clip_start_sec': 2.69573,
#   'clip_end_sec': 2.69573,
#   'mIoU': 0.017743973823454752,
#   'query': 'where did I put the plate'},
#  {'video_uid': 'a7062d19-5af7-42fe-ad8c-2d7442ddbe48',
#   'clip_uid': 'e247e74b-33d0-455d-a464-9a5be76834f6',
#   'annotation_uid': 'c29bed9d-b0c7-49e8-aee1-efc52518b712',
#   'query_idx': 2,
#   'clip_start_sec': 207.0,
#   'clip_end_sec': 208.0,
#   'mIoU': 0.030222222222222223,
#   'query': 'Where  was object the pencil before i picked it?'},
#  {'video_uid': 'f324ccbc-bef5-4d68-9722-cc99bdaaa660',
#   'clip_uid': '5e59031d-0deb-4557-a3e1-ba0ba2bb5465',
#   'annotation_uid': '5f858205-4a3d-46c8-b2e3-391e7a958987',
#   'query_idx': 9,
#   'clip_start_sec': 232.97875,
#   'clip_end_sec': 236.50409,
#   'mIoU': 0.0,
#   'query': 'Where were the napkins I folded?'},
#  {'video_uid': 'e98dd5f7-e90e-484e-b8ae-9a180882a26d',
#   'clip_uid': '1d122be0-830e-42ca-a6a4-b8ae67b0e3bc',
#   'annotation_uid': '49188ec2-6b41-4673-85a9-2e7204757057',
#   'query_idx': 0,
#   'clip_start_sec': 167.71492,
#   'clip_end_sec': 168.0,
#   'mIoU': 0.0004594625657739659,
#   'query': 'Where was the green hammer after I picked a piece of paper?'},
#  {'video_uid': '3f0bd238-228d-4796-a3e4-820308fb04b0',
#   'clip_uid': 'cbcad1bb-1b90-4838-84d7-887ee99dfdd0',
#   'annotation_uid': '1ce5b1fc-63d9-4af2-9cb7-8de53f8bbf16',
#   'query_idx': 1,
#   'clip_start_sec': 247.0,
#   'clip_end_sec': 250.0,
#   'mIoU': 0.057067064309977114,
#   'query': 'What did i put in the frying pan?'},
#  {'video_uid': 'eb81442c-a322-49ea-b243-a39d2e288b9b',
#   'clip_uid': '3f268027-765d-4988-91d9-f0f948e6f9bc',
#   'annotation_uid': '3fd7062b-6dd8-4d73-a659-9d6a22353155',
#   'query_idx': 3,
#   'clip_start_sec': 409.62122,
#   'clip_end_sec': 480.067,
#   'mIoU': 0.03322767863652366,
#   'query': 'What color was the tarpaulin  I last spread over the tent?'},
#  {'video_uid': 'fec1f883-fc5c-4257-985e-26efaec68ddc',
#   'clip_uid': '53c86be4-190d-4410-8750-179a7edc70b3',
#   'annotation_uid': '6e530270-92ce-4518-b45a-94fe5aabf02f',
#   'query_idx': 16,
#   'clip_start_sec': 1167.52658,
#   'clip_end_sec': 1173.61713,
#   'mIoU': 0.0,
#   'query': 'In what location did I see the television?'},
#  {'video_uid': 'eb5cb2b0-59e6-45da-af1b-ba86c7ab0b54',
#   'clip_uid': '27aaab35-86fc-444a-b457-241b44434c3a',
#   'annotation_uid': '1ee93cbf-504f-4dd4-887e-65a0e724cc10',
#   'query_idx': 4,
#   'clip_start_sec': 378.71482,
#   'clip_end_sec': 407.60291,
#   'mIoU': 0.2556503635104933,
#   'query': 'What did I pour from the pot into the pack?'},
#  {'video_uid': '4d89d233-dbcf-4ea2-a90f-9a2c3b42d1d5',
#   'clip_uid': 'feaf7655-ad23-4150-9e9d-552c369db96d',
#   'annotation_uid': '090121f8-b755-49b0-bba2-a9eebf45c67c',
#   'query_idx': 3,
#   'clip_start_sec': 214.63553,
#   'clip_end_sec': 230.14267,
#   'mIoU': 0.0,
#   'query': 'What wooden plank did I cut into two with the sawing machine in the garage?'},
#  {'video_uid': '413fe086-1745-4573-b75b-e7d26ff72df9',
#   'clip_uid': '75d3fc52-3776-47d4-b7fd-8074d30b06d1',
#   'annotation_uid': '93891b44-c00f-43d9-885b-92fdce39128c',
#   'query_idx': 3,
#   'clip_start_sec': 306.55159,
#   'clip_end_sec': 308.551,
#   'mIoU': 0.046475744688569146,
#   'query': 'What did I put in the refrigerator?'},
#  {'video_uid': '235b49d2-b59c-4079-81cc-ad9c01dbd2df',
#   'clip_uid': 'b5ae8df0-4825-4021-a01a-722947019865',
#   'annotation_uid': '9c19c66b-0b81-4a8e-a9af-896261e38263',
#   'query_idx': 1,
#   'clip_start_sec': 83.85124,
#   'clip_end_sec': 87.4,
#   'mIoU': 0.03857264441546864,
#   'query': 'Where was the stool before I picked it'},
#  {'video_uid': '30b9ff64-51c8-4481-ba6a-733ea2060aef',
#   'clip_uid': '39f9a8a9-9979-475b-b4f9-1fa2eda064a4',
#   'annotation_uid': '9a7530dc-6af4-4e87-973a-8112169bb643',
#   'query_idx': 1,
#   'clip_start_sec': 28.29068,
#   'clip_end_sec': 80.29,
#   'mIoU': 0.20170133699716372,
#   'query': 'Who did I talk to when I was eating the food?'},
#  {'video_uid': '824e7896-904a-4ff5-b7ee-e21df21918c2',
#   'clip_uid': 'e8842ef9-1d09-4393-ba98-ad18800c6f3e',
#   'annotation_uid': 'dc5d5acc-620e-4918-8ec3-88105cd40ba0',
#   'query_idx': 3,
#   'clip_start_sec': 121.269,
#   'clip_end_sec': 122.46945,
#   'mIoU': 0.0013080656765506206,
#   'query': 'How many rulers did I pick?'},
#  {'video_uid': '8d84ee2b-5dcb-4311-9769-a52e7b68d9e1',
#   'clip_uid': 'b9cd86ff-d01f-4faa-9d2b-c53799e47273',
#   'annotation_uid': '2b1babcf-3862-4a47-94cd-17db37987d44',
#   'query_idx': 5,
#   'clip_start_sec': 361.64149,
#   'clip_end_sec': 369.8375,
#   'mIoU': 0.0,
#   'query': 'What tool did I pick up from the ground?'},
#  {'video_uid': '85775377-b334-4bd7-8cfc-16885099cc9a',
#   'clip_uid': '35cd9ace-642f-4550-8e63-a5c2caae89ed',
#   'annotation_uid': 'c1a0d621-e201-4731-9510-dfb75ffdac92',
#   'query_idx': 0,
#   'clip_start_sec': 158.42089,
#   'clip_end_sec': 164.76382,
#   'mIoU': 0.0,
#   'query': 'Where was the car after I switched on the lights'}]

# %%
mIoUs.sort(key=lambda e: e['mIoU'], reverse=True)
mIoUs
# Out:
# [{'video_uid': '53da674a-089d-428a-a719-e322b2de002b',
#   'clip_uid': '9ab5fd9f-77e4-4438-a546-a4b6ed889f1a',
#   'annotation_uid': '0139f386-6dc6-4aad-a150-dc6745338445',
#   'query_idx': 1,
#   'clip_start_sec': 78.79924,
#   'clip_end_sec': 110.0526,
#   'mIoU': 0.7193059977419816,
#   'query': 'What did I put in the dough? '},
#  {'video_uid': '53da674a-089d-428a-a719-e322b2de002b',
#   'clip_uid': '59c01c97-9312-47f8-b911-dd789978714b',
#   'annotation_uid': '7f82729b-db06-4e3e-8a4f-2e345a7366b6',
#   'query_idx': 2,
#   'clip_start_sec': 108.86039,
#   'clip_end_sec': 137.889,
#   'mIoU': 0.6075007522615816,
#   'query': 'How many trays of pastries did I take from the oven?'},
#  {'video_uid': 'adf65602-f5ee-456a-a098-db19a521ce38',
#   'clip_uid': 'a185abe1-ae2e-4ab4-aa5c-d2f45abfd7c9',
#   'annotation_uid': '043c0c21-82d5-4f6d-8971-4aff968143ee',
#   'query_idx': 3,
#   'clip_start_sec': 175.43704,
#   'clip_end_sec': 175.43704,
#   'mIoU': 0.5514652763835325,
#   'query': 'how many are the boxes'},
#  {'video_uid': 'a4728450-c05c-4d51-91e4-348f571d74bc',
#   'clip_uid': '3231822a-fc8b-4207-b0b8-5cbb1344cb2f',
#   'annotation_uid': 'a89efc9c-f6bb-472a-a8c6-bdae52f82638',
#   'query_idx': 0,
#   'clip_start_sec': 8.97254,
#   'clip_end_sec': 17.51162,
#   'mIoU': 0.5362022554305378,
#   'query': 'What kitchen tool did I cut the springer onions with?'},
#  {'video_uid': '1c7426ad-b6ba-4494-897c-537dd4a201e9',
#   'clip_uid': '0aca0078-b6ab-41fb-9dc5-a70b8ad137b2',
#   'annotation_uid': 'd05845b4-cd60-4e38-b179-9b6c23ee6099',
#   'query_idx': 2,
#   'clip_start_sec': 284.8643,
#   'clip_end_sec': 295.97068,
#   'mIoU': 0.49694918323858894,
#   'query': 'How many tools did I pick from underneath the work table?'},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': '75958c37-1002-4b2d-a455-168b0ebcaf8a',
#   'annotation_uid': '69ba2583-8c8b-41e0-8294-a7f61a71727e',
#   'query_idx': 4,
#   'clip_start_sec': 147.30506,
#   'clip_end_sec': 154.305,
#   'mIoU': 0.47865210958408444,
#   'query': 'What color is the cloth i folded?'},
#  {'video_uid': '3fc60e72-91ad-4320-bd07-1cf753f4a5f1',
#   'clip_uid': '740a9d13-cf77-4e7d-91b5-a3ebf6d270ec',
#   'annotation_uid': 'ba973d7d-473e-4df9-955b-d590cd9436f8',
#   'query_idx': 0,
#   'clip_start_sec': 442.95713,
#   'clip_end_sec': 449.836,
#   'mIoU': 0.4321734457344716,
#   'query': 'who did I talk to at the walkway?'},
#  {'video_uid': '80f3dd0d-6ad9-4691-9de5-dc01a834bc0a',
#   'clip_uid': '679cfee6-7da1-4701-b75a-9e34abb9400a',
#   'annotation_uid': 'a62a6082-2f04-48a5-a5ad-ddf8b2a07229',
#   'query_idx': 1,
#   'clip_start_sec': 41.84264,
#   'clip_end_sec': 45.842,
#   'mIoU': 0.415342718935099,
#   'query': 'Where was piece of wood before i picked it'},
#  {'video_uid': 'bd3a319e-0573-4802-a6d1-6d89910098e8',
#   'clip_uid': 'a35ac9e4-bb20-460e-9c9d-67806ab9d13f',
#   'annotation_uid': 'e93f1e16-136d-4e25-8b89-1fa3d6c2b74e',
#   'query_idx': 4,
#   'clip_start_sec': 79.0,
#   'clip_end_sec': 85.4,
#   'mIoU': 0.40038920831490515,
#   'query': 'How many bottles of coke was in the pack I took?'},
#  {'video_uid': '80f3dd0d-6ad9-4691-9de5-dc01a834bc0a',
#   'clip_uid': '2bbc6cdf-b662-498e-9a9f-231dd5ac2a9e',
#   'annotation_uid': 'efa7da94-3c84-48d3-a8cf-d9bc0ba377da',
#   'query_idx': 3,
#   'clip_start_sec': 166.366,
#   'clip_end_sec': 170.366,
#   'mIoU': 0.37162710321346565,
#   'query': 'What beverage did I drink? '},
#  {'video_uid': 'bd3a319e-0573-4802-a6d1-6d89910098e8',
#   'clip_uid': 'a35ac9e4-bb20-460e-9c9d-67806ab9d13f',
#   'annotation_uid': '0faae1b8-380e-43a1-9868-b5c847a5a8f1',
#   'query_idx': 1,
#   'clip_start_sec': 81.33784,
#   'clip_end_sec': 81.33784,
#   'mIoU': 0.3520153013061368,
#   'query': 'where was coke before I picked it?'},
#  {'video_uid': '53da674a-089d-428a-a719-e322b2de002b',
#   'clip_uid': 'e4cf448f-e442-4e19-bf87-1eee8fbf59d8',
#   'annotation_uid': 'b4118c52-8258-4f95-8812-03bfd8fef42e',
#   'query_idx': 6,
#   'clip_start_sec': 351.81719,
#   'clip_end_sec': 358.61341,
#   'mIoU': 0.3264648546884923,
#   'query': 'How many oven tray did I put in the oven ? '},
#  {'video_uid': '8e748fd1-e30e-4bf6-a04f-5f570ca075ac',
#   'clip_uid': 'a325ce85-cae5-4faa-99bb-7272918fcf19',
#   'annotation_uid': 'e7aae1c9-3c56-4f63-81ad-bd55fe122448',
#   'query_idx': 2,
#   'clip_start_sec': 403.3868,
#   'clip_end_sec': 408.57537,
#   'mIoU': 0.31805362259929,
#   'query': 'When did I talk to the cashier at the store'},
#  {'video_uid': '824e7896-904a-4ff5-b7ee-e21df21918c2',
#   'clip_uid': 'da0092ba-0247-4438-9172-4f60f00be608',
#   'annotation_uid': 'f5a0f3fe-dfd0-4b08-b913-79b55841b56b',
#   'query_idx': 5,
#   'clip_start_sec': 229.61754,
#   'clip_end_sec': 232.92673,
#   'mIoU': 0.28671066879284685,
#   'query': 'Where is the orange waste bin?'},
#  {'video_uid': 'eb5cb2b0-59e6-45da-af1b-ba86c7ab0b54',
#   'clip_uid': '27aaab35-86fc-444a-b457-241b44434c3a',
#   'annotation_uid': '1ee93cbf-504f-4dd4-887e-65a0e724cc10',
#   'query_idx': 4,
#   'clip_start_sec': 378.71482,
#   'clip_end_sec': 407.60291,
#   'mIoU': 0.2556503635104933,
#   'query': 'What did I pour from the pot into the pack?'},
#  {'video_uid': '42c08776-8832-4d37-8844-3ce89e405c62',
#   'clip_uid': 'f15dbeca-63e7-43b5-b1a6-7896bc28b08c',
#   'annotation_uid': '08a04c87-bb88-4cc0-9f4f-8760931d3996',
#   'query_idx': 2,
#   'clip_start_sec': 11.7226,
#   'clip_end_sec': 17.0,
#   'mIoU': 0.25478013760887014,
#   'query': 'who did l talk to in front of the boutique store'},
#  {'video_uid': 'd526d862-080f-4b3e-9894-6ff997f5d6ac',
#   'clip_uid': 'b69e6150-0309-4202-bf4a-9a342f80d6d7',
#   'annotation_uid': 'cfa46eb6-259c-4591-8e1e-0c748dd68bad',
#   'query_idx': 1,
#   'clip_start_sec': 23.95484,
#   'clip_end_sec': 27.22756,
#   'mIoU': 0.23437339092678613,
#   'query': 'What color is the colander?'},
#  {'video_uid': '1dcc108c-8bd4-42ad-b2c5-03662be62eda',
#   'clip_uid': '47c24350-cc10-4ec6-8407-24f778981a82',
#   'annotation_uid': '59f62bf1-b6cf-4417-9388-18dc2e02c976',
#   'query_idx': 0,
#   'clip_start_sec': 10.0,
#   'clip_end_sec': 12.0,
#   'mIoU': 0.2339148238357341,
#   'query': 'Where did I close the car door?'},
#  {'video_uid': 'a330bb33-7cef-48d8-81e8-e0abd9fd0896',
#   'clip_uid': '611edaf1-8c1b-4093-b057-00e1e99ce1fc',
#   'annotation_uid': '5dd8ac88-ac29-4f5c-86ae-6b49edfc4eca',
#   'query_idx': 0,
#   'clip_start_sec': 0.0,
#   'clip_end_sec': 35.0,
#   'mIoU': 0.22812698772975376,
#   'query': 'who did I talk to at a rocky area?'},
#  {'video_uid': 'a743a90e-f46c-4e55-a94d-a7f11c771207',
#   'clip_uid': '751201ad-5397-4956-a4f2-d73fb969b6c5',
#   'annotation_uid': '685813b4-c725-4e13-9c08-05abbccb7eab',
#   'query_idx': 4,
#   'clip_start_sec': 352.75895,
#   'clip_end_sec': 352.75895,
#   'mIoU': 0.2173996250692572,
#   'query': 'Where was mobile phone before i picked it?'},
#  {'video_uid': '30b9ff64-51c8-4481-ba6a-733ea2060aef',
#   'clip_uid': '39f9a8a9-9979-475b-b4f9-1fa2eda064a4',
#   'annotation_uid': '9a7530dc-6af4-4e87-973a-8112169bb643',
#   'query_idx': 1,
#   'clip_start_sec': 28.29068,
#   'clip_end_sec': 80.29,
#   'mIoU': 0.20170133699716372,
#   'query': 'Who did I talk to when I was eating the food?'},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': 'f748feb9-9a15-4f2b-9b65-186f90107c7c',
#   'annotation_uid': 'ed904e38-6e0e-4e4e-9bfe-d4b28127fde4',
#   'query_idx': 12,
#   'clip_start_sec': 1097.18994,
#   'clip_end_sec': 1102.69444,
#   'mIoU': 0.18680406268581531,
#   'query': 'What did I bring out of the fridge'},
#  {'video_uid': '7d6d6cae-0601-485d-b900-482b4254e9f8',
#   'clip_uid': '5bff21b4-ac93-450f-a189-b2fb7cff4d99',
#   'annotation_uid': '89e5cc1e-500c-4452-9a3f-2d9e02cb8396',
#   'query_idx': 7,
#   'clip_start_sec': 58.66908,
#   'clip_end_sec': 60.97166,
#   'mIoU': 0.17410761321713888,
#   'query': 'Where did I put the phone'},
#  {'video_uid': 'b68709fe-2a73-49c3-a468-afcf56ab234c',
#   'clip_uid': '956488d0-1b28-41b5-a13f-7f1b72e1c2c7',
#   'annotation_uid': 'bd742c40-e95d-46ba-83aa-da36dac6720c',
#   'query_idx': 0,
#   'clip_start_sec': 1.533,
#   'clip_end_sec': 3.53331,
#   'mIoU': 0.16405150113945582,
#   'query': 'where was the mud balance before i picked it?'},
#  {'video_uid': '0c6ab491-c45e-4cbc-b6b2-a709cc856a9c',
#   'clip_uid': '71e0d3e7-4706-4eb3-9a7a-85d01f46259f',
#   'annotation_uid': 'd6111b4f-0b33-431c-bc69-4873edc4ff12',
#   'query_idx': 6,
#   'clip_start_sec': 359.3743,
#   'clip_end_sec': 382.45465,
#   'mIoU': 0.16241536939264886,
#   'query': 'Where are my glasses'},
#  {'video_uid': '624a6c0a-a4cb-4073-b501-48e4b6b679e4',
#   'clip_uid': 'a611f8f9-a866-4b40-a9c6-34175a62f178',
#   'annotation_uid': '8d8266f3-f317-4f7c-bb89-797656be03df',
#   'query_idx': 0,
#   'clip_start_sec': 12.67211,
#   'clip_end_sec': 23.672,
#   'mIoU': 0.16054679842636882,
#   'query': 'What tool did I use on the engine?'},
#  {'video_uid': '18e84829-901a-414d-8a2b-d1d2b3244db7',
#   'clip_uid': 'f4c804be-6a83-4f29-9e45-81bf6a2b00cb',
#   'annotation_uid': '35703a64-29d5-4bd1-876c-2926cf1b7418',
#   'query_idx': 1,
#   'clip_start_sec': 68.79329,
#   'clip_end_sec': 71.0,
#   'mIoU': 0.1597764205197486,
#   'query': 'Where was the box?'},
#  {'video_uid': '73773748-14ac-40ba-9ef8-d5a70865aeea',
#   'clip_uid': 'f2f4fd65-681a-41ab-b6cf-c7feb025a040',
#   'annotation_uid': '88f6d6d0-a58a-45b9-8a9e-c342acc1722d',
#   'query_idx': 4,
#   'clip_start_sec': 275.5428,
#   'clip_end_sec': 283.57731,
#   'mIoU': 0.15782500476041053,
#   'query': 'In what room did I bring out cassette from a drawer?'},
#  {'video_uid': '86343e9e-b932-41d3-ad6f-83f2c2fe5486',
#   'clip_uid': '4ba774a8-cd2a-4889-9971-cc91f5c1afd4',
#   'annotation_uid': 'c0d973f1-9c48-4268-bc4a-db8062199894',
#   'query_idx': 5,
#   'clip_start_sec': 190.0,
#   'clip_end_sec': 193.0,
#   'mIoU': 0.138,
#   'query': 'Where Was the plate before I picked it?'},
#  {'video_uid': 'c40736ec-e68f-43f6-960d-7d8bd467b1c7',
#   'clip_uid': '89193dbc-0ffa-4ee2-9ea8-c434ce177310',
#   'annotation_uid': 'dc31cf2a-4584-4122-86f1-488ada791faf',
#   'query_idx': 0,
#   'clip_start_sec': 2.4326,
#   'clip_end_sec': 4.0,
#   'mIoU': 0.12088719088671944,
#   'query': 'Where was the stainless bowl before I picked it up?'},
#  {'video_uid': '18a3840b-7463-43c4-9aa9-b1d8e486fa84',
#   'clip_uid': 'a538b7bc-5ec2-496a-8bbe-9d6d38381a39',
#   'annotation_uid': 'f5f878e3-60dd-4ee1-8080-a11774ba3294',
#   'query_idx': 1,
#   'clip_start_sec': 90.3572,
#   'clip_end_sec': 101.76579,
#   'mIoU': 0.10937106653814861,
#   'query': 'Where did I throw the bottle I drank from?'},
#  {'video_uid': '80f3dd0d-6ad9-4691-9de5-dc01a834bc0a',
#   'clip_uid': '2bbc6cdf-b662-498e-9a9f-231dd5ac2a9e',
#   'annotation_uid': 'efa7da94-3c84-48d3-a8cf-d9bc0ba377da',
#   'query_idx': 1,
#   'clip_start_sec': 7.332,
#   'clip_end_sec': 12.018,
#   'mIoU': 0.10593329318219824,
#   'query': 'Where was the phone before I operate it?'},
#  {'video_uid': 'fb7cc35d-3272-44a4-b8f2-15cd24fa345b',
#   'clip_uid': 'ab094ea2-9251-4f10-945b-c2ab00c5282e',
#   'annotation_uid': 'd2ba7cbc-d85e-43e2-8078-193aa9e99c24',
#   'query_idx': 3,
#   'clip_start_sec': 99.26734,
#   'clip_end_sec': 127.796,
#   'mIoU': 0.09505240610733183,
#   'query': 'What time did i chop the carrots?'},
#  {'video_uid': 'f2a257e6-01da-4856-b145-2947ce5dcb0e',
#   'clip_uid': '498d6197-deb0-481c-9cfd-8d516122638d',
#   'annotation_uid': '31be573d-9c1a-4d9b-8200-7e81157cd3ca',
#   'query_idx': 0,
#   'clip_start_sec': 0.0,
#   'clip_end_sec': 1.62346,
#   'mIoU': 0.09053064553531989,
#   'query': 'Where was the hacksaw before I picked it ? '},
#  {'video_uid': 'bedaa131-deae-4279-9fd4-5b6ab552644c',
#   'clip_uid': 'eceaedd8-2560-441c-a084-214db47d509a',
#   'annotation_uid': '24a91700-0ec3-4b36-9e0e-1668253a463f',
#   'query_idx': 3,
#   'clip_start_sec': 132.42393,
#   'clip_end_sec': 159.0,
#   'mIoU': 0.0873508037209302,
#   'query': 'in what location did l use wrench '},
#  {'video_uid': '25beabfc-48c0-4f81-b419-c47297aecf6f',
#   'clip_uid': 'c9885f38-fa92-42f0-b998-42b1139b5b5f',
#   'annotation_uid': '1e25aa63-50aa-4039-953f-324bea8c3f72',
#   'query_idx': 0,
#   'clip_start_sec': 131.86819,
#   'clip_end_sec': 172.00473,
#   'mIoU': 0.08696057258093051,
#   'query': 'Who did I interact with when I coupled the disc cutter saw?'},
#  {'video_uid': '25beabfc-48c0-4f81-b419-c47297aecf6f',
#   'clip_uid': 'c9885f38-fa92-42f0-b998-42b1139b5b5f',
#   'annotation_uid': '1e25aa63-50aa-4039-953f-324bea8c3f72',
#   'query_idx': 0,
#   'clip_start_sec': 131.86819,
#   'clip_end_sec': 172.00473,
#   'mIoU': 0.08696057258093051,
#   'query': 'Who did I interact with when I coupled the disc cutter saw?'},
#  {'video_uid': '3534864b-2289-4aaf-b3ed-10eeeee7acd2',
#   'clip_uid': '8acaf6f6-5396-4df6-98e6-13baea8f8af8',
#   'annotation_uid': '37fabd23-dbd9-4a7d-9f33-d6507eb0fd76',
#   'query_idx': 1,
#   'clip_start_sec': 28.66799,
#   'clip_end_sec': 28.66799,
#   'mIoU': 0.07518719561971747,
#   'query': 'Where did i put the lid?'},
#  {'video_uid': '5802f3e8-c11e-4403-b6c4-7504257be73c',
#   'clip_uid': 'b810fff6-0df0-479a-b58c-012e42e4f7b3',
#   'annotation_uid': '91e86f79-bde0-4a07-bec6-9d7c3bb4aa82',
#   'query_idx': 6,
#   'clip_start_sec': 281.43285,
#   'clip_end_sec': 323.42196,
#   'mIoU': 0.07374696782682869,
#   'query': 'What machine did I blow?'},
#  {'video_uid': '3ee7070a-fe81-49a9-97a2-902268af9985',
#   'clip_uid': 'a40dce18-488d-4acc-b754-fcd56c204db1',
#   'annotation_uid': '617f76c2-b046-4be0-b44b-e49439b0e416',
#   'query_idx': 5,
#   'clip_start_sec': 261.78895,
#   'clip_end_sec': 262.931,
#   'mIoU': 0.07118982996785568,
#   'query': 'Where was the towel?'},
#  {'video_uid': '404cc1c1-f7a0-4e16-9a39-b8e2d5d9ae59',
#   'clip_uid': '1c597fc1-7bd0-4325-abbc-645e3ec71866',
#   'annotation_uid': '5f5ccaa6-6b65-4f5c-b2f3-57d5ad659fc1',
#   'query_idx': 0,
#   'clip_start_sec': 9.58492,
#   'clip_end_sec': 14.30371,
#   'mIoU': 0.07031326376811595,
#   'query': 'Where did I put the nylon bag?'},
#  {'video_uid': '168f91fd-53c2-4eee-9d2d-e25e1ad73438',
#   'clip_uid': '9466f5f0-09f2-4b9f-bb4a-3de270fd425b',
#   'annotation_uid': '8f1c9f14-22e7-4c6b-9906-9adbaaa82bf8',
#   'query_idx': 8,
#   'clip_start_sec': 402.1677,
#   'clip_end_sec': 480.067,
#   'mIoU': 0.06820505358552417,
#   'query': 'Where is the frame?'},
#  {'video_uid': '225a1ffe-3e7e-4ff8-a47e-2e80989077fe',
#   'clip_uid': '2c1724ce-f438-4d63-a699-8a7f65e3cbd9',
#   'annotation_uid': '41315e00-678a-435a-9a9b-a7316b8a40fd',
#   'query_idx': 6,
#   'clip_start_sec': 197.36281,
#   'clip_end_sec': 198.54994,
#   'mIoU': 0.06602339349137215,
#   'query': 'Where was the cloth before I picked it? '},
#  {'video_uid': '6243586b-a8df-4c37-95f8-da7f4f5d57d6',
#   'clip_uid': 'b352dc19-c601-4740-9559-6db99ea782e9',
#   'annotation_uid': 'ebee2c27-b4e6-4ed2-a2ea-c2360d025cf0',
#   'query_idx': 3,
#   'clip_start_sec': 269.34156,
#   'clip_end_sec': 270.265,
#   'mIoU': 0.06550963204500737,
#   'query': 'Where did I take a packet from?'},
#  {'video_uid': '85775377-b334-4bd7-8cfc-16885099cc9a',
#   'clip_uid': '35cd9ace-642f-4550-8e63-a5c2caae89ed',
#   'annotation_uid': 'cd65d2c2-8b2d-4873-989a-061b91be1bd8',
#   'query_idx': 2,
#   'clip_start_sec': 154.05798,
#   'clip_end_sec': 158.057,
#   'mIoU': 0.06133567788125367,
#   'query': 'Did I close the circuit breaker box? '},
#  {'video_uid': '3f0bd238-228d-4796-a3e4-820308fb04b0',
#   'clip_uid': 'cbcad1bb-1b90-4838-84d7-887ee99dfdd0',
#   'annotation_uid': '1ce5b1fc-63d9-4af2-9cb7-8de53f8bbf16',
#   'query_idx': 1,
#   'clip_start_sec': 247.0,
#   'clip_end_sec': 250.0,
#   'mIoU': 0.057067064309977114,
#   'query': 'What did i put in the frying pan?'},
#  {'video_uid': '477feff8-a1ff-4f43-b726-273ca0fa47e9',
#   'clip_uid': '61de3e3f-8862-4d68-ab4a-2a26e81916d1',
#   'annotation_uid': '0d83a02d-0ed0-439a-98b6-5b9d479f8880',
#   'query_idx': 2,
#   'clip_start_sec': 65.7271,
#   'clip_end_sec': 67.0,
#   'mIoU': 0.05663624713324973,
#   'query': 'what color was the towel?'},
#  {'video_uid': 'd88d4e54-5e5e-4c08-9a87-80958f9e4ec1',
#   'clip_uid': '0edc229a-eb4a-473c-b66b-550c19eecd42',
#   'annotation_uid': '96996e4f-02ed-4086-9712-377833ae29b2',
#   'query_idx': 7,
#   'clip_start_sec': 146.35499,
#   'clip_end_sec': 151.88186,
#   'mIoU': 0.05551399420950294,
#   'query': 'In what location did I see my black sneakers?'},
#  {'video_uid': '243e800d-fc75-473d-b944-a95844e13a78',
#   'clip_uid': '2c2bda8d-69a3-4a90-9ad6-f6715bc99f39',
#   'annotation_uid': 'c7377c33-3b3d-4447-9459-1becffdfc106',
#   'query_idx': 3,
#   'clip_start_sec': 192.25264,
#   'clip_end_sec': 193.18593,
#   'mIoU': 0.05347033784615381,
#   'query': 'What electronic gadget did I pick?'},
#  {'video_uid': '9c50dcc2-f3af-4529-afce-fec005c78a39',
#   'clip_uid': '4ab42038-79a6-433c-905d-f1426561b9f8',
#   'annotation_uid': 'a1c3bef5-3b62-4d78-962b-71564cc2e946',
#   'query_idx': 2,
#   'clip_start_sec': 83.34764,
#   'clip_end_sec': 87.42505,
#   'mIoU': 0.052553284444444445,
#   'query': 'Where did I put the boots?'},
#  {'video_uid': '413fe086-1745-4573-b75b-e7d26ff72df9',
#   'clip_uid': '75d3fc52-3776-47d4-b7fd-8074d30b06d1',
#   'annotation_uid': '93891b44-c00f-43d9-885b-92fdce39128c',
#   'query_idx': 3,
#   'clip_start_sec': 306.55159,
#   'clip_end_sec': 308.551,
#   'mIoU': 0.046475744688569146,
#   'query': 'What did I put in the refrigerator?'},
#  {'video_uid': '7b3bea48-bd62-46b7-888d-2cc6e4bbd11b',
#   'clip_uid': '992cee60-a8af-423f-8a40-5b14208fcc1a',
#   'annotation_uid': '1ec79f94-bc66-4a6f-8a25-29d5c639f15f',
#   'query_idx': 0,
#   'clip_start_sec': 0.0,
#   'clip_end_sec': 79.64063,
#   'mIoU': 0.041642159477124185,
#   'query': 'Where is the wooden tray?'},
#  {'video_uid': 'c0f702e1-d2e3-4277-8981-7177d106174a',
#   'clip_uid': '8bf16989-e870-44bb-863c-c6745e69f6fb',
#   'annotation_uid': '0bc1549b-fd67-4166-8ba2-4019975312af',
#   'query_idx': 5,
#   'clip_start_sec': 302.99422,
#   'clip_end_sec': 315.994,
#   'mIoU': 0.04054251279911223,
#   'query': 'where was the machete before I picked it?'},
#  {'video_uid': '9930414f-b998-4217-b6b5-aa686236fdf8',
#   'clip_uid': 'c7873f07-7b9c-4794-9a56-fdebeeceee68',
#   'annotation_uid': '1a8ce90c-2273-495a-9366-52345df0f7d1',
#   'query_idx': 7,
#   'clip_start_sec': 205.02932,
#   'clip_end_sec': 216.624,
#   'mIoU': 0.04038545569482569,
#   'query': 'Where is the cream bag?'},
#  {'video_uid': '235b49d2-b59c-4079-81cc-ad9c01dbd2df',
#   'clip_uid': 'b5ae8df0-4825-4021-a01a-722947019865',
#   'annotation_uid': '9c19c66b-0b81-4a8e-a9af-896261e38263',
#   'query_idx': 1,
#   'clip_start_sec': 83.85124,
#   'clip_end_sec': 87.4,
#   'mIoU': 0.03857264441546864,
#   'query': 'Where was the stool before I picked it'},
#  {'video_uid': '235b49d2-b59c-4079-81cc-ad9c01dbd2df',
#   'clip_uid': 'b5ae8df0-4825-4021-a01a-722947019865',
#   'annotation_uid': '9c19c66b-0b81-4a8e-a9af-896261e38263',
#   'query_idx': 1,
#   'clip_start_sec': 83.85124,
#   'clip_end_sec': 87.4,
#   'mIoU': 0.03857264441546864,
#   'query': 'Where was the stool before I picked it'},
#  {'video_uid': '18a3840b-7463-43c4-9aa9-b1d8e486fa84',
#   'clip_uid': 'c0a634a9-3dbe-44f8-9a04-7718d2a2762e',
#   'annotation_uid': 'd5ca0729-597f-4d3b-9aa0-3fae2015c997',
#   'query_idx': 2,
#   'clip_start_sec': 68.21018,
#   'clip_end_sec': 89.01975,
#   'mIoU': 0.03769580251826814,
#   'query': 'Where did I carry the table to'},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': '58fa07ae-2992-4dc9-842a-e5a73ee3d345',
#   'annotation_uid': '1cf514d5-81b8-47b6-b378-d3efa5829592',
#   'query_idx': 0,
#   'clip_start_sec': 70.34414,
#   'clip_end_sec': 81.74455,
#   'mIoU': 0.035890179629629655,
#   'query': 'What object did I light'},
#  {'video_uid': '66a0900b-069d-48bf-9071-f4e659f8a9d0',
#   'clip_uid': 'cd7ccaeb-9d60-4aab-ab83-ea223004bad9',
#   'annotation_uid': 'aa303ded-59e2-46bc-81ed-a46d0a0413dd',
#   'query_idx': 0,
#   'clip_start_sec': 6.0,
#   'clip_end_sec': 7.0,
#   'mIoU': 0.03428571428571429,
#   'query': 'where was the nylon before I picked it up'},
#  {'video_uid': 'eb81442c-a322-49ea-b243-a39d2e288b9b',
#   'clip_uid': '3f268027-765d-4988-91d9-f0f948e6f9bc',
#   'annotation_uid': '3fd7062b-6dd8-4d73-a659-9d6a22353155',
#   'query_idx': 3,
#   'clip_start_sec': 409.62122,
#   'clip_end_sec': 480.067,
#   'mIoU': 0.03322767863652366,
#   'query': 'What color was the tarpaulin  I last spread over the tent?'},
#  {'video_uid': 'eb81442c-a322-49ea-b243-a39d2e288b9b',
#   'clip_uid': '3f268027-765d-4988-91d9-f0f948e6f9bc',
#   'annotation_uid': '3fd7062b-6dd8-4d73-a659-9d6a22353155',
#   'query_idx': 3,
#   'clip_start_sec': 409.62122,
#   'clip_end_sec': 480.067,
#   'mIoU': 0.03322767863652366,
#   'query': 'What color was the tarpaulin  I last spread over the tent?'},
#  {'video_uid': '50d413f2-5709-475d-8999-6135dcd7d63f',
#   'clip_uid': 'c8f4c698-167f-44f8-b624-3fb69660a7ce',
#   'annotation_uid': '99d4a11a-192a-474b-8af7-b1155fb0e9fa',
#   'query_idx': 3,
#   'clip_start_sec': 359.0,
#   'clip_end_sec': 360.0,
#   'mIoU': 0.03151515151515151,
#   'query': 'where was the grey soldering gun before I picked it?'},
#  {'video_uid': 'a7062d19-5af7-42fe-ad8c-2d7442ddbe48',
#   'clip_uid': 'e247e74b-33d0-455d-a464-9a5be76834f6',
#   'annotation_uid': 'c29bed9d-b0c7-49e8-aee1-efc52518b712',
#   'query_idx': 2,
#   'clip_start_sec': 207.0,
#   'clip_end_sec': 208.0,
#   'mIoU': 0.030222222222222223,
#   'query': 'Where  was object the pencil before i picked it?'},
#  {'video_uid': '7c5eb718-99b2-48ac-bb1c-ef0158a6361b',
#   'clip_uid': '61a0bd1c-c14b-41bb-a97e-05cd58207e5a',
#   'annotation_uid': 'a0169aab-73df-4e20-ba53-2f3247115275',
#   'query_idx': 6,
#   'clip_start_sec': 424.6101,
#   'clip_end_sec': 480.034,
#   'mIoU': 0.02307749034443394,
#   'query': 'Where was the blue plank?'},
#  {'video_uid': '7d6d6cae-0601-485d-b900-482b4254e9f8',
#   'clip_uid': '522b72ce-f947-4cdb-8ebb-ebdfdbe6f04f',
#   'annotation_uid': 'b4c56cdf-bfc9-4a6c-a57e-8c5fa417f401',
#   'query_idx': 6,
#   'clip_start_sec': 435.25698,
#   'clip_end_sec': 444.684,
#   'mIoU': 0.021417052646703027,
#   'query': 'In what location did I last see the napkin I used in cleaning my hands?'},
#  {'video_uid': '939dcf5d-c88c-4f93-b300-982adaff5ce3',
#   'clip_uid': 'fc4bfef7-e079-4783-92e1-b768cfac8125',
#   'annotation_uid': '6f2fcdde-43ad-46f9-8778-40659a86218d',
#   'query_idx': 2,
#   'clip_start_sec': 36.42862,
#   'clip_end_sec': 39.17055,
#   'mIoU': 0.020310592592592568,
#   'query': 'Did I leave the rod standing.'},
#  {'video_uid': '805989f6-0696-4de2-ad9b-0f194e0ac48d',
#   'clip_uid': 'eaf8d34a-0e20-45d0-a288-569df047461e',
#   'annotation_uid': '2ce0dc4d-d51a-4a07-93a1-fe0c3fdc3c78',
#   'query_idx': 7,
#   'clip_start_sec': 6.3983,
#   'clip_end_sec': 6.3983,
#   'mIoU': 0.020037537537537536,
#   'query': 'Where did i put the bolt'},
#  {'video_uid': '5afd7421-fb6b-4c65-a09a-716f79a7a935',
#   'clip_uid': '67db788f-6307-416f-8385-d4053e5777b9',
#   'annotation_uid': '406dfeda-3276-4bab-b495-12acad39afad',
#   'query_idx': 2,
#   'clip_start_sec': 99.45426,
#   'clip_end_sec': 100.0,
#   'mIoU': 0.019176049382715873,
#   'query': 'where was the screwdriver before i took it?'},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': '70cef020-51e7-429e-af75-f87747b3daad',
#   'annotation_uid': '3529aee9-4752-4d79-8fec-1b9343b81295',
#   'query_idx': 4,
#   'clip_start_sec': 285.0,
#   'clip_end_sec': 289.0,
#   'mIoU': 0.01834694096217722,
#   'query': 'what did I put in the plastic container?'},
#  {'video_uid': 'e0c4d2c7-fd50-4c50-b40e-e1eda4a5708b',
#   'clip_uid': 'aa2afb03-41d8-42fc-a111-982d9319f1c4',
#   'annotation_uid': '3a023968-376e-4f92-a218-be14db8de55c',
#   'query_idx': 0,
#   'clip_start_sec': 2.69573,
#   'clip_end_sec': 2.69573,
#   'mIoU': 0.017743973823454752,
#   'query': 'where did I put the plate'},
#  {'video_uid': '243e800d-fc75-473d-b944-a95844e13a78',
#   'clip_uid': '8aadc754-fb37-4eae-ba7f-47949b5b3835',
#   'annotation_uid': '76cea951-4e11-4d38-af56-206713badd3a',
#   'query_idx': 2,
#   'clip_start_sec': 258.017,
#   'clip_end_sec': 261.0,
#   'mIoU': 0.01680263814616758,
#   'query': 'How many chair pillow are on the grey chair?'},
#  {'video_uid': '45a02f60-e694-4bef-9c31-d5a71f556122',
#   'clip_uid': 'c6470548-81a3-4d9c-8bee-87a955948d5c',
#   'annotation_uid': '861763f7-591e-4f0e-8244-d91f2f7e0243',
#   'query_idx': 0,
#   'clip_start_sec': 1.08028,
#   'clip_end_sec': 5.08,
#   'mIoU': 0.016087673427041503,
#   'query': 'where did the car pass before I started walking'},
#  {'video_uid': 'd526d862-080f-4b3e-9894-6ff997f5d6ac',
#   'clip_uid': 'b69e6150-0309-4202-bf4a-9a342f80d6d7',
#   'annotation_uid': 'b1d8a893-a87e-4b7a-8a1c-9b8f8fde9f41',
#   'query_idx': 14,
#   'clip_start_sec': 393.88749,
#   'clip_end_sec': 393.88749,
#   'mIoU': 0.015815513626834383,
#   'query': 'where is my pipe metal?'},
#  {'video_uid': '82ace2ff-4a87-4abe-ba45-3965bbc13658',
#   'clip_uid': 'e9becd62-c5ea-4104-9d81-781a78bb7dbe',
#   'annotation_uid': '5f5e4631-c34d-46c2-b1cd-f7504e0c06df',
#   'query_idx': 2,
#   'clip_start_sec': 5.23825,
#   'clip_end_sec': 8.47592,
#   'mIoU': 0.01484023295582601,
#   'query': 'What did I put in the Oven?'},
#  {'video_uid': 'bd3a319e-0573-4802-a6d1-6d89910098e8',
#   'clip_uid': 'a35ac9e4-bb20-460e-9c9d-67806ab9d13f',
#   'annotation_uid': '0faae1b8-380e-43a1-9868-b5c847a5a8f1',
#   'query_idx': 3,
#   'clip_start_sec': 141.2592,
#   'clip_end_sec': 141.2592,
#   'mIoU': 0.014384477929102676,
#   'query': 'who did I interact with when I was picked  snack?'},
#  {'video_uid': '216c7a1a-7ec3-4aa0-a465-e37e7b5fd2f3',
#   'clip_uid': '093259bc-5b71-4204-be7b-5f7b5b5f20cb',
#   'annotation_uid': '5ecca0b5-c8b3-4e76-8332-712f83bf9b90',
#   'query_idx': 7,
#   'clip_start_sec': 895.78,
#   'clip_end_sec': 899.78,
#   'mIoU': 0.01422855219878635,
#   'query': 'where was the phone before I touched it'},
#  {'video_uid': '9bf859f2-62ff-4f2e-9eb8-ef69feb4d343',
#   'clip_uid': 'ca304360-2402-4241-a6eb-5ff2f300546f',
#   'annotation_uid': '994f38c0-b2b8-4677-8bb1-10955188c558',
#   'query_idx': 2,
#   'clip_start_sec': 135.0,
#   'clip_end_sec': 146.0,
#   'mIoU': 0.014023430728894296,
#   'query': 'what color was the file?'},
#  {'video_uid': 'f442873e-6f2b-493f-a6db-718cd20a732a',
#   'clip_uid': '055a1e31-aa3f-4695-a8ee-6c0c6351c936',
#   'annotation_uid': '5616defe-9963-4c08-95da-03ce3d28bf94',
#   'query_idx': 5,
#   'clip_start_sec': 420.09955,
#   'clip_end_sec': 421.0,
#   'mIoU': 0.013865390769230431,
#   'query': 'where did I put the phone?'},
#  {'video_uid': 'c0f702e1-d2e3-4277-8981-7177d106174a',
#   'clip_uid': '8bf16989-e870-44bb-863c-c6745e69f6fb',
#   'annotation_uid': '0bc1549b-fd67-4166-8ba2-4019975312af',
#   'query_idx': 4,
#   'clip_start_sec': 269.8815,
#   'clip_end_sec': 269.8815,
#   'mIoU': 0.013610676030361068,
#   'query': 'what was the color of the hoe?'},
#  {'video_uid': '3fc60e72-91ad-4320-bd07-1cf753f4a5f1',
#   'clip_uid': '740a9d13-cf77-4e7d-91b5-a3ebf6d270ec',
#   'annotation_uid': 'ba973d7d-473e-4df9-955b-d590cd9436f8',
#   'query_idx': 2,
#   'clip_start_sec': 353.90828,
#   'clip_end_sec': 361.114,
#   'mIoU': 0.013420264174930053,
#   'query': 'In what location did I see the parked car?'},
#  {'video_uid': 'b68709fe-2a73-49c3-a468-afcf56ab234c',
#   'clip_uid': '956488d0-1b28-41b5-a13f-7f1b72e1c2c7',
#   'annotation_uid': 'bd742c40-e95d-46ba-83aa-da36dac6720c',
#   'query_idx': 2,
#   'clip_start_sec': 114.66639,
#   'clip_end_sec': 114.66639,
#   'mIoU': 0.013333333333333332,
#   'query': 'what color was the bucket?'},
#  {'video_uid': '4dc58b9f-75f4-4f27-aa19-2b8ebd1daad6',
#   'clip_uid': 'e4dd3b6b-7801-4a19-bb66-9a0d8721f387',
#   'annotation_uid': '98fe7e4c-e1d1-46a8-be59-296dc81b872d',
#   'query_idx': 2,
#   'clip_start_sec': 413.90219,
#   'clip_end_sec': 415.902,
#   'mIoU': 0.012288955895061533,
#   'query': 'Where is the  orange cable?'},
#  {'video_uid': '1938c632-f575-49dd-8ae0-e48dbb467920',
#   'clip_uid': '7db32b15-9ea6-4a44-a103-cc04471ce4f7',
#   'annotation_uid': 'c44e960a-8c34-432c-acc9-5c25963af193',
#   'query_idx': 1,
#   'clip_start_sec': 71.17935,
#   'clip_end_sec': 75.0,
#   'mIoU': 0.011986352941176472,
#   'query': 'how many eggs did I pick?'},
#  {'video_uid': '624a6c0a-a4cb-4073-b501-48e4b6b679e4',
#   'clip_uid': '903e0bf6-db7e-4b1c-8cb9-867317963fde',
#   'annotation_uid': 'de967307-36f6-4906-8fcf-704fe39da1e7',
#   'query_idx': 1,
#   'clip_start_sec': 230.81,
#   'clip_end_sec': 243.81,
#   'mIoU': 0.011662912912912913,
#   'query': 'Who was with me when I repaired the engine?'},
#  {'video_uid': '4ce119de-0f42-4bd1-b387-9e19643fdddc',
#   'clip_uid': 'e1c79556-e8af-4e26-bc4c-633100277239',
#   'annotation_uid': 'd8fb0c3d-39b1-4bb2-b800-fc56f12ab120',
#   'query_idx': 8,
#   'clip_start_sec': 381.26346,
#   'clip_end_sec': 390.66762,
#   'mIoU': 0.011626874285985536,
#   'query': 'Where was the microwave?'},
#  {'video_uid': 'eb81442c-a322-49ea-b243-a39d2e288b9b',
#   'clip_uid': 'd22d3eaf-9350-46b9-99d0-39fb50e246c0',
#   'annotation_uid': 'bbbec6de-db2c-440a-9f40-3999be74370e',
#   'query_idx': 1,
#   'clip_start_sec': 189.04035,
#   'clip_end_sec': 189.04035,
#   'mIoU': 0.011388376629755939,
#   'query': 'Where did I put a stone'},
#  {'video_uid': 'd526d862-080f-4b3e-9894-6ff997f5d6ac',
#   'clip_uid': 'b69e6150-0309-4202-bf4a-9a342f80d6d7',
#   'annotation_uid': 'cfa46eb6-259c-4591-8e1e-0c748dd68bad',
#   'query_idx': 2,
#   'clip_start_sec': 36.14568,
#   'clip_end_sec': 39.94075,
#   'mIoU': 0.01124465185185186,
#   'query': 'What color is the air fryer?'},
#  {'video_uid': 'c864505c-9d49-4da4-bf7e-254b4c348c03',
#   'clip_uid': '96453857-2454-418f-bbd6-3f5f8b3eadbd',
#   'annotation_uid': 'bad8cc0e-a998-4c05-872d-347d5eb580c8',
#   'query_idx': 5,
#   'clip_start_sec': 148.62933,
#   'clip_end_sec': 148.62933,
#   'mIoU': 0.011090990990990991,
#   'query': 'What color of funnel was hanged on the wall?'},
#  {'video_uid': '935f591f-9184-4ea8-869a-4c56d7029aa4',
#   'clip_uid': 'dcbafb3e-c8d1-43ce-a604-7662da9f2591',
#   'annotation_uid': '7fc66bc0-348b-4d23-a50f-8b735f4d297b',
#   'query_idx': 1,
#   'clip_start_sec': 66.9493,
#   'clip_end_sec': 70.59702,
#   'mIoU': 0.011014599337024514,
#   'query': 'Where is the glass jug?'},
#  {'video_uid': 'b3ba6f28-2506-4121-ad08-c5b96b410a1f',
#   'clip_uid': '28c1f367-b80b-4072-a54c-fa17b207bf7b',
#   'annotation_uid': '12525c2c-1f9d-41ce-86fc-35942d49645e',
#   'query_idx': 2,
#   'clip_start_sec': 152.34253,
#   'clip_end_sec': 160.54564,
#   'mIoU': 0.010667178960116373,
#   'query': 'What wood did I hit with the claw tool?'},
#  {'video_uid': '9e7fa594-5774-4681-a034-50a5c83cff8f',
#   'clip_uid': 'a8b49a23-cc44-47f9-ae8a-95584e537b8d',
#   'annotation_uid': '156c14c9-0c7a-4d40-b0bc-ab8e417f6438',
#   'query_idx': 4,
#   'clip_start_sec': 309.26636,
#   'clip_end_sec': 313.188,
#   'mIoU': 0.010401978261563027,
#   'query': 'in what location did I see the door rug '},
#  {'video_uid': '45a02f60-e694-4bef-9c31-d5a71f556122',
#   'clip_uid': 'c6470548-81a3-4d9c-8bee-87a955948d5c',
#   'annotation_uid': 'b11c94db-3574-4d78-906c-da6a9b659c8a',
#   'query_idx': 3,
#   'clip_start_sec': 194.70449,
#   'clip_end_sec': 203.83524,
#   'mIoU': 0.010212023026315797,
#   'query': 'How many tents?'},
#  {'video_uid': 'f6a0d8f5-468d-4e47-bfca-e7d13b75f26d',
#   'clip_uid': '81ad10fe-c74e-4359-8779-186f46680e2c',
#   'annotation_uid': '62c40b8f-fd95-43f9-9b00-cb253c0abc2c',
#   'query_idx': 6,
#   'clip_start_sec': 404.45524,
#   'clip_end_sec': 415.236,
#   'mIoU': 0.009779735678078067,
#   'query': 'What did i pour into the steel bowl ?'},
#  {'video_uid': '0971527a-6cd3-4c82-9d94-09b3565f4505',
#   'clip_uid': '755ac5c3-b6cd-42da-ac72-c413d0be986a',
#   'annotation_uid': 'f35a2b55-622a-433e-a218-90769e474831',
#   'query_idx': 3,
#   'clip_start_sec': 178.31767,
#   'clip_end_sec': 187.0,
#   'mIoU': 0.00942761610962568,
#   'query': 'Where did I put the cable ties?'},
#  {'video_uid': '9bf859f2-62ff-4f2e-9eb8-ef69feb4d343',
#   'clip_uid': 'ca304360-2402-4241-a6eb-5ff2f300546f',
#   'annotation_uid': '994f38c0-b2b8-4677-8bb1-10955188c558',
#   'query_idx': 5,
#   'clip_start_sec': 287.0,
#   'clip_end_sec': 296.0,
#   'mIoU': 0.008901829106191587,
#   'query': 'how many books were in the container?'},
#  {'video_uid': '805989f6-0696-4de2-ad9b-0f194e0ac48d',
#   'clip_uid': 'eaf8d34a-0e20-45d0-a288-569df047461e',
#   'annotation_uid': '2ce0dc4d-d51a-4a07-93a1-fe0c3fdc3c78',
#   'query_idx': 1,
#   'clip_start_sec': 277.513,
#   'clip_end_sec': 282.013,
#   'mIoU': 0.008844038629899582,
#   'query': 'What did i put on the power drill'},
#  {'video_uid': '624a6c0a-a4cb-4073-b501-48e4b6b679e4',
#   'clip_uid': '903e0bf6-db7e-4b1c-8cb9-867317963fde',
#   'annotation_uid': '3a8dc748-9cdb-47ba-988e-87bdc446368e',
#   'query_idx': 2,
#   'clip_start_sec': 138.301,
#   'clip_end_sec': 142.301,
#   'mIoU': 0.008526645768025079,
#   'query': 'Where did I put the hammer?'},
#  {'video_uid': '86343e9e-b932-41d3-ad6f-83f2c2fe5486',
#   'clip_uid': '4ba774a8-cd2a-4889-9971-cc91f5c1afd4',
#   'annotation_uid': '45b0646b-3e1f-4e48-b295-d7de15701c52',
#   'query_idx': 1,
#   'clip_start_sec': 167.27719,
#   'clip_end_sec': 173.6,
#   'mIoU': 0.008174946262626267,
#   'query': 'What did I put in the bowl?'},
#  {'video_uid': '50d413f2-5709-475d-8999-6135dcd7d63f',
#   'clip_uid': 'c8f4c698-167f-44f8-b624-3fb69660a7ce',
#   'annotation_uid': '99d4a11a-192a-474b-8af7-b1155fb0e9fa',
#   'query_idx': 4,
#   'clip_start_sec': 409.0,
#   'clip_end_sec': 411.0,
#   'mIoU': 0.008053181386514719,
#   'query': 'Where was the wrench before I picked it?'},
#  {'video_uid': '59f00ff2-4e01-4498-ab40-4713217686bc',
#   'clip_uid': 'e2171ff4-e32e-437f-9792-f37613e86598',
#   'annotation_uid': '6a1bcd20-6a17-41a4-8c20-68b2c9d8f42d',
#   'query_idx': 3,
#   'clip_start_sec': 238.773,
#   'clip_end_sec': 241.773,
#   'mIoU': 0.0076924766319762345,
#   'query': 'how many nails?'},
#  {'video_uid': '8a6a3316-d682-4a76-81db-b244081765c9',
#   'clip_uid': 'e776ca99-4a92-4444-8a1f-fa55bfa381e0',
#   'annotation_uid': '0f7085e5-1816-4599-83d7-c04189b1218f',
#   'query_idx': 6,
#   'clip_start_sec': 366.60256,
#   'clip_end_sec': 370.76756,
#   'mIoU': 0.006112534378437874,
#   'query': 'How many sandy patches were on the field?'},
#  {'video_uid': '04994ce8-9d47-44d6-a7b0-42b395e69390',
#   'clip_uid': 'a18c5454-8d7f-4380-944a-21854635d7f9',
#   'annotation_uid': '2e99957a-639e-44ff-a557-932cd806f88b',
#   'query_idx': 5,
#   'clip_start_sec': 249.97277,
#   'clip_end_sec': 262.0,
#   'mIoU': 0.006063911949485946,
#   'query': 'Where did I put tile cutter?'},
#  {'video_uid': '53da674a-089d-428a-a719-e322b2de002b',
#   'clip_uid': '5438349a-2d91-4d73-b763-f10f04c77d37',
#   'annotation_uid': '086f0f77-d388-47a8-a8ac-2bd81b834b90',
#   'query_idx': 5,
#   'clip_start_sec': 320.73651,
#   'clip_end_sec': 329.0,
#   'mIoU': 0.006037252968036522,
#   'query': 'where is the dough'},
#  {'video_uid': 'c864505c-9d49-4da4-bf7e-254b4c348c03',
#   'clip_uid': '89f7ac43-956d-4d7e-b8a1-442ecff20ad6',
#   'annotation_uid': '05947447-1e02-47ad-9209-26a868968bef',
#   'query_idx': 4,
#   'clip_start_sec': 243.46158,
#   'clip_end_sec': 243.46158,
#   'mIoU': 0.005720642302188416,
#   'query': 'What did I put in the steel bowl?'},
#  {'video_uid': '2d442f12-3595-4b2d-b8c5-583b65c0c49f',
#   'clip_uid': 'f32cb53d-4a80-499c-bb32-cefef3abe205',
#   'annotation_uid': 'c46d08ce-3b1d-4071-9c86-1d37ecf7ef13',
#   'query_idx': 1,
#   'clip_start_sec': 87.86366,
#   'clip_end_sec': 91.958,
#   'mIoU': 0.005213899851612906,
#   'query': 'In what location did I see the cat?'},
#  {'video_uid': '3534864b-2289-4aaf-b3ed-10eeeee7acd2',
#   'clip_uid': 'bccc3bde-d9b2-4edb-9b1f-a3f42dd07b3e',
#   'annotation_uid': 'f8fc39c5-c320-46f3-95f9-33b6e3c712ea',
#   'query_idx': 0,
#   'clip_start_sec': 100.35182,
#   'clip_end_sec': 102.60116,
#   'mIoU': 0.00495092825396823,
#   'query': 'How many dough cutters did I pick?'},
#  {'video_uid': 'ad851441-1f15-467e-83d8-48c764e220a8',
#   'clip_uid': '6c2849cb-d6bb-432e-b4ae-8b8c4837ad8b',
#   'annotation_uid': '5925d86c-d9f1-4430-85e2-0161ef01ae74',
#   'query_idx': 4,
#   'clip_start_sec': 467.89268,
#   'clip_end_sec': 474.04765,
#   'mIoU': 0.004264844374308097,
#   'query': 'Where is the luggage?'},
#  {'video_uid': '0dbd615d-fde9-4936-a605-6f5659cd113e',
#   'clip_uid': '7c1f3062-ae3e-4db0-b490-940cc2a7b949',
#   'annotation_uid': 'cd803af4-846c-422a-9c13-bda6a4df49d8',
#   'query_idx': 3,
#   'clip_start_sec': 281.02744,
#   'clip_end_sec': 282.866,
#   'mIoU': 0.0032323896741175105,
#   'query': 'How many pieces of cups are ion top of the fridge?'},
#  {'video_uid': 'c40736ec-e68f-43f6-960d-7d8bd467b1c7',
#   'clip_uid': '89193dbc-0ffa-4ee2-9ea8-c434ce177310',
#   'annotation_uid': '294d2807-8bdd-4267-a4f1-a0ce18ff7969',
#   'query_idx': 1,
#   'clip_start_sec': 105.85125,
#   'clip_end_sec': 108.58912,
#   'mIoU': 0.0027947000244200253,
#   'query': 'Where is the scissors?'},
#  {'video_uid': '432cb803-6be5-47bc-8443-6bb5b9051667',
#   'clip_uid': 'cc6270fd-3c0d-4dda-bcb4-52cefc0224d7',
#   'annotation_uid': '2bc5aa4c-3114-497e-9d13-e229277fe11b',
#   'query_idx': 1,
#   'clip_start_sec': 41.39507,
#   'clip_end_sec': 43.879,
#   'mIoU': 0.0027035972789115656,
#   'query': 'Where did I put the bucket?'},
#  {'video_uid': 'c0f702e1-d2e3-4277-8981-7177d106174a',
#   'clip_uid': '8bf16989-e870-44bb-863c-c6745e69f6fb',
#   'annotation_uid': '2ccb1927-953d-422a-9765-cb7f6db4ca5c',
#   'query_idx': 7,
#   'clip_start_sec': 185.16182,
#   'clip_end_sec': 190.591,
#   'mIoU': 0.0024536100865203436,
#   'query': 'Where was the stainless cup?'},
#  {'video_uid': 'e0c4d2c7-fd50-4c50-b40e-e1eda4a5708b',
#   'clip_uid': 'aa2afb03-41d8-42fc-a111-982d9319f1c4',
#   'annotation_uid': '85d10fda-c58f-4e67-b593-2c53e28038b5',
#   'query_idx': 4,
#   'clip_start_sec': 290.26702,
#   'clip_end_sec': 294.5247,
#   'mIoU': 0.0023196821351316715,
#   'query': 'Where did I put the glass cup?'},
#  {'video_uid': '5935de98-30c0-4357-9e89-1c1395c1e2c1',
#   'clip_uid': 'e722f056-dc03-4de5-a861-e379f513b004',
#   'annotation_uid': 'ece2ca6e-19d4-4222-8047-854c6f09f23e',
#   'query_idx': 1,
#   'clip_start_sec': 111.8039,
#   'clip_end_sec': 112.63898,
#   'mIoU': 0.0023140318488529153,
#   'query': 'what did I put on  the kitchen slab?'},
#  {'video_uid': 'd61475bb-fd97-43e3-8b7d-a242064a9d10',
#   'clip_uid': '1945d70d-bb9d-4523-aa31-7cfedb76b6c6',
#   'annotation_uid': 'b303aa34-c8e8-444e-a7f0-a850f3a8d178',
#   'query_idx': 0,
#   'clip_start_sec': 73.22931,
#   'clip_end_sec': 74.20862,
#   'mIoU': 0.0022464458781361963,
#   'query': 'Where was the container after I dropped it?'},
#  {'video_uid': '935f591f-9184-4ea8-869a-4c56d7029aa4',
#   'clip_uid': '90602dc0-4c33-4b26-b4d5-c63105c40187',
#   'annotation_uid': 'c6a76e69-c3c3-41d2-aa72-ccbc231fb56a',
#   'query_idx': 1,
#   'clip_start_sec': 468.86195,
#   'clip_end_sec': 480.067,
#   'mIoU': 0.002204431221539882,
#   'query': 'In what  location did I see the red sack?'},
#  {'video_uid': '8a6a3316-d682-4a76-81db-b244081765c9',
#   'clip_uid': 'e776ca99-4a92-4444-8a1f-fa55bfa381e0',
#   'annotation_uid': 'a2508f63-21cd-4bd6-8b94-dba2d71745c8',
#   'query_idx': 0,
#   'clip_start_sec': 97.84858,
#   'clip_end_sec': 103.0,
#   'mIoU': 0.0021633259842519692,
#   'query': 'who was I with when I first boarded the golf cart'},
#  {'video_uid': 'd61475bb-fd97-43e3-8b7d-a242064a9d10',
#   'clip_uid': '7bf24899-4a05-46d4-b47d-36ce045643d8',
#   'annotation_uid': '6b7b963d-351a-4108-ad85-d33fcd5c304c',
#   'query_idx': 1,
#   'clip_start_sec': 14.89415,
#   'clip_end_sec': 16.18649,
#   'mIoU': 0.002029740350877192,
#   'query': 'What did I put on the table?'},
#  {'video_uid': 'fec1f883-fc5c-4257-985e-26efaec68ddc',
#   'clip_uid': '53c86be4-190d-4410-8750-179a7edc70b3',
#   'annotation_uid': '6e530270-92ce-4518-b45a-94fe5aabf02f',
#   'query_idx': 10,
#   'clip_start_sec': 785.11291,
#   'clip_end_sec': 795.65722,
#   'mIoU': 0.0018140748387096765,
#   'query': 'What color was the wristwatch I wore?'},
#  {'video_uid': '51fc62f8-00f4-44e3-af9c-7ebb63da6c3d',
#   'clip_uid': 'c7accb5b-fc3c-415b-986e-59643d94cdc6',
#   'annotation_uid': 'f9184458-9051-46d1-9e24-840f40504045',
#   'query_idx': 3,
#   'clip_start_sec': 40.84447,
#   'clip_end_sec': 42.04447,
#   'mIoU': 0.0017297297297297234,
#   'query': 'where did I put the bowl?'},
#  {'video_uid': '356dd07e-8165-494c-9be8-b82d314bf88d',
#   'clip_uid': 'ba5b8b24-2335-40c0-86c9-bfd76620e1fa',
#   'annotation_uid': 'ee530e0f-5a2e-469c-b089-a666aea6aeb2',
#   'query_idx': 2,
#   'clip_start_sec': 409.93459,
#   'clip_end_sec': 418.51348,
#   'mIoU': 0.0015001337704918035,
#   'query': 'What color is the packet I lifted. '},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': 'f748feb9-9a15-4f2b-9b65-186f90107c7c',
#   'annotation_uid': 'd167c9f6-d252-40a8-b876-650ee2f6b1a5',
#   'query_idx': 7,
#   'clip_start_sec': 528.85236,
#   'clip_end_sec': 534.2977,
#   'mIoU': 0.0013666735686274478,
#   'query': 'In what room did i leave dough mixer?'},
#  {'video_uid': '603ecf93-d2c1-4611-a690-76afd18935c8',
#   'clip_uid': 'cf1470f1-9a03-4944-95dd-7f8410bb6cc8',
#   'annotation_uid': '1ba5bf7a-bb9e-4594-b679-da6f7c52a05a',
#   'query_idx': 1,
#   'clip_start_sec': 69.056,
#   'clip_end_sec': 70.256,
#   'mIoU': 0.0013473684210526349,
#   'query': 'Where was the black container before I picked it up?'},
#  {'video_uid': '824e7896-904a-4ff5-b7ee-e21df21918c2',
#   'clip_uid': 'e8842ef9-1d09-4393-ba98-ad18800c6f3e',
#   'annotation_uid': 'dc5d5acc-620e-4918-8ec3-88105cd40ba0',
#   'query_idx': 3,
#   'clip_start_sec': 121.269,
#   'clip_end_sec': 122.46945,
#   'mIoU': 0.0013080656765506206,
#   'query': 'How many rulers did I pick?'},
#  {'video_uid': '5d090853-467e-4f95-9f9e-ac0582023111',
#   'clip_uid': '95daa74b-1edf-4f33-96ff-e0c7eb0c0dbb',
#   'annotation_uid': 'da1cb157-f680-480c-b1ee-680ab5de3c78',
#   'query_idx': 1,
#   'clip_start_sec': 270.445,
#   'clip_end_sec': 273.445,
#   'mIoU': 0.00125,
#   'query': 'In what location did I see frame?'},
#  {'video_uid': '182dffe9-d2bf-4a7d-b1d8-137470f0143d',
#   'clip_uid': 'ee379d11-2535-4300-9d9e-dc9d9c53d94f',
#   'annotation_uid': '73417dbc-f91c-4cb3-bd0f-9101babef11c',
#   'query_idx': 4,
#   'clip_start_sec': 470.26718,
#   'clip_end_sec': 473.0,
#   'mIoU': 0.0011399415824314496,
#   'query': 'Where did I put the lid?'},
#  {'video_uid': '86ebad37-486c-4687-b50e-67627a4be7a2',
#   'clip_uid': '3ef4d3b5-2a79-42f0-9609-509f886e7f93',
#   'annotation_uid': 'b8f6defe-914c-4fd4-8cc3-24e3f8a58f12',
#   'query_idx': 5,
#   'clip_start_sec': 303.48192,
#   'clip_end_sec': 304.33238,
#   'mIoU': 0.0009511723684210507,
#   'query': 'Where was the piece of paper before i picked it?'},
#  {'video_uid': '86ebad37-486c-4687-b50e-67627a4be7a2',
#   'clip_uid': '3ef4d3b5-2a79-42f0-9609-509f886e7f93',
#   'annotation_uid': 'b8f6defe-914c-4fd4-8cc3-24e3f8a58f12',
#   'query_idx': 5,
#   'clip_start_sec': 303.48192,
#   'clip_end_sec': 304.33238,
#   'mIoU': 0.0009511723684210507,
#   'query': 'Where was the piece of paper before i picked it?'},
#  {'video_uid': '216c7a1a-7ec3-4aa0-a465-e37e7b5fd2f3',
#   'clip_uid': '093259bc-5b71-4204-be7b-5f7b5b5f20cb',
#   'annotation_uid': '5ecca0b5-c8b3-4e76-8332-712f83bf9b90',
#   'query_idx': 5,
#   'clip_start_sec': 601.438,
#   'clip_end_sec': 603.438,
#   'mIoU': 0.0008939645557627766,
#   'query': 'What machine did I touch in the house?'},
#  {'video_uid': '3534864b-2289-4aaf-b3ed-10eeeee7acd2',
#   'clip_uid': '8acaf6f6-5396-4df6-98e6-13baea8f8af8',
#   'annotation_uid': '37fabd23-dbd9-4a7d-9f33-d6507eb0fd76',
#   'query_idx': 16,
#   'clip_start_sec': 747.40772,
#   'clip_end_sec': 749.0,
#   'mIoU': 0.0008289951332244034,
#   'query': 'What flour bag did i fold?'},
#  {'video_uid': 'cd7c3bc6-24df-465c-9b63-a7961a7558de',
#   'clip_uid': 'c664f078-9b34-4a58-b949-180ac4bc0980',
#   'annotation_uid': 'f4dcaa0b-92a0-4168-ac6b-ad7df26d8a15',
#   'query_idx': 2,
#   'clip_start_sec': 88.27018,
#   'clip_end_sec': 90.0,
#   'mIoU': 0.0008164342182890872,
#   'query': 'what did I pick from the wall'},
#  {'video_uid': 'c864505c-9d49-4da4-bf7e-254b4c348c03',
#   'clip_uid': '96453857-2454-418f-bbd6-3f5f8b3eadbd',
#   'annotation_uid': 'a23e1d01-7ac4-47f1-ac6e-3c66ebe78447',
#   'query_idx': 9,
#   'clip_start_sec': 376.92763,
#   'clip_end_sec': 377.819,
#   'mIoU': 0.000764294524793384,
#   'query': 'Did i close the ice cube shelf?'},
#  {'video_uid': '363b5839-a7c3-4c2e-b966-9530e38045a1',
#   'clip_uid': '2b19ee03-d94f-4c1f-822d-d4c00a2066cc',
#   'annotation_uid': '3c445280-f531-44d0-8581-7c9248092f53',
#   'query_idx': 1,
#   'clip_start_sec': 159.08509,
#   'clip_end_sec': 159.76209,
#   'mIoU': 0.0007522222222222138,
#   'query': 'Where did I put the folding rule?'},
#  {'video_uid': '18a3840b-7463-43c4-9aa9-b1d8e486fa84',
#   'clip_uid': 'a538b7bc-5ec2-496a-8bbe-9d6d38381a39',
#   'annotation_uid': '36e9d168-44dc-43e7-8189-13a7fbfe64bc',
#   'query_idx': 5,
#   'clip_start_sec': 247.0,
#   'clip_end_sec': 248.0,
#   'mIoU': 0.0006993006993006993,
#   'query': 'In what location did I see the hacksaw?'},
#  {'video_uid': '8912a138-6c68-424d-8be5-59e0d4f5c173',
#   'clip_uid': '810d230f-2771-4a2d-ad09-9b04714930d3',
#   'annotation_uid': '330a22b7-a72f-4cc4-bb28-6d007ce1ed68',
#   'query_idx': 5,
#   'clip_start_sec': 367.77272,
#   'clip_end_sec': 368.772,
#   'mIoU': 0.0006746194092826996,
#   'query': 'In what location did i see the sandals'},
#  {'video_uid': '4d89d233-dbcf-4ea2-a90f-9a2c3b42d1d5',
#   'clip_uid': '3d688dd9-8a21-43bd-9d1b-9be73b0b26bb',
#   'annotation_uid': 'fa6199c4-090e-437f-b7fe-6cfb158cacb3',
#   'query_idx': 1,
#   'clip_start_sec': 452.05372,
#   'clip_end_sec': 453.6149,
#   'mIoU': 0.0006661034666666577,
#   'query': 'In what Location did I last see the small plastic chair?'},
#  {'video_uid': 'e98dd5f7-e90e-484e-b8ae-9a180882a26d',
#   'clip_uid': '1d122be0-830e-42ca-a6a4-b8ae67b0e3bc',
#   'annotation_uid': '49188ec2-6b41-4673-85a9-2e7204757057',
#   'query_idx': 4,
#   'clip_start_sec': 327.39086,
#   'clip_end_sec': 328.0,
#   'mIoU': 0.0006346956803029825,
#   'query': 'Where did I put the black torch?'},
#  {'video_uid': 'b68709fe-2a73-49c3-a468-afcf56ab234c',
#   'clip_uid': '9093c341-5f95-4402-a2dd-6a84aa42bf1f',
#   'annotation_uid': '3c52dcc8-31e1-4a6a-b28e-f0dc30a800e9',
#   'query_idx': 6,
#   'clip_start_sec': 358.70621,
#   'clip_end_sec': 359.24082,
#   'mIoU': 0.0005197597222222092,
#   'query': 'Where is the scrapper?'},
#  {'video_uid': 'ae2dfec4-6094-4ff3-a404-a8a6ab1e0f02',
#   'clip_uid': '245f3b76-ef46-48d1-b37c-afe73efbf1cf',
#   'annotation_uid': '012e4b4f-2304-4304-8546-d185c919caa5',
#   'query_idx': 5,
#   'clip_start_sec': 320.16684,
#   'clip_end_sec': 321.07857,
#   'mIoU': 0.0005065166666666857,
#   'query': 'Where was the drill machine?'},
#  {'video_uid': 'fec1f883-fc5c-4257-985e-26efaec68ddc',
#   'clip_uid': '53c86be4-190d-4410-8750-179a7edc70b3',
#   'annotation_uid': '53f3aa88-cbbc-4672-8823-fdb5edc61390',
#   'query_idx': 7,
#   'clip_start_sec': 722.23741,
#   'clip_end_sec': 723.0,
#   'mIoU': 0.00046154340442658697,
#   'query': 'Did I leave the door open?'},
#  {'video_uid': 'e98dd5f7-e90e-484e-b8ae-9a180882a26d',
#   'clip_uid': '1d122be0-830e-42ca-a6a4-b8ae67b0e3bc',
#   'annotation_uid': '49188ec2-6b41-4673-85a9-2e7204757057',
#   'query_idx': 0,
#   'clip_start_sec': 167.71492,
#   'clip_end_sec': 168.0,
#   'mIoU': 0.0004594625657739659,
#   'query': 'Where was the green hammer after I picked a piece of paper?'},
#  {'video_uid': '06fb8090-16a4-42c3-819e-f0e95ddba24d',
#   'clip_uid': '5d466470-4de6-4318-9806-f5a0c24807de',
#   'annotation_uid': 'a3a64d6f-f22c-4fee-8979-7b9fa82d1ccb',
#   'query_idx': 0,
#   'clip_start_sec': 157.72822,
#   'clip_end_sec': 158.49429,
#   'mIoU': 0.000389547751469894,
#   'query': 'where was pantry pack before I picked it?'},
#  {'video_uid': '3534864b-2289-4aaf-b3ed-10eeeee7acd2',
#   'clip_uid': '8acaf6f6-5396-4df6-98e6-13baea8f8af8',
#   'annotation_uid': '58195979-ad36-4b82-9d26-be59455e1d4d',
#   'query_idx': 6,
#   'clip_start_sec': 390.71503,
#   'clip_end_sec': 392.53518,
#   'mIoU': 0.000373530116338862,
#   'query': 'How many jugs of water did I pour into the mixer?'},
#  {'video_uid': 'a94b8e4a-8921-4dcb-a79b-2c079e299e3a',
#   'clip_uid': '4a37144f-63cd-4729-809c-f05ec1839036',
#   'annotation_uid': '55fd815b-7ba3-4ba8-ba30-ad97d073beec',
#   'query_idx': 3,
#   'clip_start_sec': 19.34333,
#   'clip_end_sec': 20.0,
#   'mIoU': 0.00022333898373983683,
#   'query': 'where was the sandals?'},
#  {'video_uid': '3534864b-2289-4aaf-b3ed-10eeeee7acd2',
#   'clip_uid': 'bccc3bde-d9b2-4edb-9b1f-a3f42dd07b3e',
#   'annotation_uid': '1947bdf0-b455-4e1b-aefb-f952a834e4a5',
#   'query_idx': 6,
#   'clip_start_sec': 165.10395,
#   'clip_end_sec': 168.0,
#   'mIoU': 0.0,
#   'query': 'where is the yellow scooper?'},
#  {'video_uid': 'd8217a15-4527-4557-94c5-df4eb78b748a',
#   'clip_uid': 'ba265640-5261-4e3f-9b52-dda27d34898a',
#   'annotation_uid': '765eaaee-1f20-407e-ac10-6810c574d8d5',
#   'query_idx': 6,
#   'clip_start_sec': 402.92199,
#   'clip_end_sec': 421.666,
#   'mIoU': 0.0,
#   'query': 'Who did I interact with when adjusting a watch on the hand?'},
#  {'video_uid': '3534864b-2289-4aaf-b3ed-10eeeee7acd2',
#   'clip_uid': '8acaf6f6-5396-4df6-98e6-13baea8f8af8',
#   'annotation_uid': '37fabd23-dbd9-4a7d-9f33-d6507eb0fd76',
#   'query_idx': 26,
#   'clip_start_sec': 1194.70555,
#   'clip_end_sec': 1196.0,
#   'mIoU': 0.0,
#   'query': 'what dough shaper did i push?'},
#  {'video_uid': '7f70ae0a-d097-4dda-9afa-318188dfce2d',
#   'clip_uid': 'b2e24b02-4d9e-436e-8557-fe02b75c9f5f',
#   'annotation_uid': 'd3ddd7fd-8a3b-4201-b612-d9f78d9742ab',
#   'query_idx': 0,
#   'clip_start_sec': 0.0,
#   'clip_end_sec': 2.0,
#   'mIoU': 0.0,
#   'query': 'where were the asparagus before i picked them up'},
# ...
#   'query_idx': 4,
#   'clip_start_sec': 399.70651,
#   'clip_end_sec': 402.75195,
#   'mIoU': 0.0,
#   'query': 'Did I switch off the mower'},
#  {'video_uid': '512db5d5-6aa3-4777-a1ba-1ea1718db929',
#   'clip_uid': '1c865785-9ac6-4f16-baa4-97405aacad6a',
#   'annotation_uid': '61110650-804f-4d64-8753-f5d4023133ac',
#   'query_idx': 6,
#   'clip_start_sec': 297.17024,
#   'clip_end_sec': 298.81887,
#   'mIoU': 0.0,
#   'query': 'Where is the can after I dropped it ?'},
#  {'video_uid': 'bbd117a9-e969-4e15-9840-70101a864dd5',
#   'clip_uid': '1ff34d9f-1c5a-40d8-98ee-8d3cbf48ebc3',
#   'annotation_uid': '80064f7f-ba68-4316-8f8f-d7934fc7694e',
#   'query_idx': 0,
#   'clip_start_sec': 1.78944,
#   'clip_end_sec': 23.0,
#   'mIoU': 0.0,
#   'query': 'Where is the pack of vegetable?'},
#  {'video_uid': '94cdabf3-c078-4ad4-a3a1-c42c8fc3f4ad',
#   'clip_uid': 'b01fdd44-357c-4566-b487-d9ff21e56c2e',
#   'annotation_uid': '7ae246f9-e526-454e-b655-ef0d9276fe22',
#   'query_idx': 1,
#   'clip_start_sec': 75.22579,
#   'clip_end_sec': 83.13353,
#   'mIoU': 0.0,
#   'query': 'What did I remove from the plastic wrap?'},
#  {'video_uid': '0971527a-6cd3-4c82-9d94-09b3565f4505',
#   'clip_uid': '755ac5c3-b6cd-42da-ac72-c413d0be986a',
#   'annotation_uid': 'c3e465af-6e74-4309-aa04-8bb923ea85e0',
#   'query_idx': 6,
#   'clip_start_sec': 464.53621,
#   'clip_end_sec': 467.31073,
#   'mIoU': 0.0,
#   'query': 'Where is the bucket'},
#  {'video_uid': 'f082242c-309f-48a1-97fa-5c1d6bd255fb',
#   'clip_uid': '5d531ac1-010a-4e67-ba1a-96e485b14968',
#   'annotation_uid': '3eb83361-fc41-4f9c-bb0c-978bebbf1175',
#   'query_idx': 2,
#   'clip_start_sec': 49.0,
#   'clip_end_sec': 51.7,
#   'mIoU': 0.0,
#   'query': 'Where was the knife before I picked it ?'},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': '58fa07ae-2992-4dc9-842a-e5a73ee3d345',
#   'annotation_uid': '1cf514d5-81b8-47b6-b378-d3efa5829592',
#   'query_idx': 4,
#   'clip_start_sec': 249.81585,
#   'clip_end_sec': 253.51039,
#   'mIoU': 0.0,
#   'query': 'where wass the dustbin'},
#  {'video_uid': '824e7896-904a-4ff5-b7ee-e21df21918c2',
#   'clip_uid': 'e8842ef9-1d09-4393-ba98-ad18800c6f3e',
#   'annotation_uid': 'fd3c3693-1eef-4b96-bb4a-72361856b371',
#   'query_idx': 3,
#   'clip_start_sec': 360.78731,
#   'clip_end_sec': 374.3276,
#   'mIoU': 0.0,
#   'query': 'Where is the cutting board?'},
#  {'video_uid': '824e7896-904a-4ff5-b7ee-e21df21918c2',
#   'clip_uid': 'da0092ba-0247-4438-9172-4f60f00be608',
#   'annotation_uid': 'f5a0f3fe-dfd0-4b08-b913-79b55841b56b',
#   'query_idx': 7,
#   'clip_start_sec': 234.49205,
#   'clip_end_sec': 236.94273,
#   'mIoU': 0.0,
#   'query': 'Did I leave the tap open?'},
#  {'video_uid': 'c8d88b2c-d6ed-4ef3-a7a1-e3b3dac0550f',
#   'clip_uid': 'cc2a687e-e871-4319-85c9-c0161678903d',
#   'annotation_uid': '3d910daf-00b9-4951-8927-685c7c2f9158',
#   'query_idx': 0,
#   'clip_start_sec': 81.35669,
#   'clip_end_sec': 81.67481,
#   'mIoU': 0.0,
#   'query': 'Who did I talk to in the living room?'},
#  {'video_uid': '42c08776-8832-4d37-8844-3ce89e405c62',
#   'clip_uid': 'f15dbeca-63e7-43b5-b1a6-7896bc28b08c',
#   'annotation_uid': '08a04c87-bb88-4cc0-9f4f-8760931d3996',
#   'query_idx': 4,
#   'clip_start_sec': 181.39365,
#   'clip_end_sec': 209.0,
#   'mIoU': 0.0,
#   'query': 'where did l saw the dummy doll'},
#  {'video_uid': '245cde61-d0a0-49c8-840d-e484b5f71a04',
#   'clip_uid': '12babcc1-a848-4882-869e-b6e8cc963c2c',
#   'annotation_uid': '9473d9e3-8872-4944-904f-5755a9b831a9',
#   'query_idx': 7,
#   'clip_start_sec': 372.2871,
#   'clip_end_sec': 398.9827,
#   'mIoU': 0.0,
#   'query': 'Where was the pot lid before I covered the pot?'},
#  {'video_uid': '404cc1c1-f7a0-4e16-9a39-b8e2d5d9ae59',
#   'clip_uid': '1c597fc1-7bd0-4325-abbc-645e3ec71866',
#   'annotation_uid': '5f5ccaa6-6b65-4f5c-b2f3-57d5ad659fc1',
#   'query_idx': 7,
#   'clip_start_sec': 323.54713,
#   'clip_end_sec': 325.90154,
#   'mIoU': 0.0,
#   'query': 'How many rolls of paper towel did I cut'},
#  {'video_uid': '6243586b-a8df-4c37-95f8-da7f4f5d57d6',
#   'clip_uid': 'b352dc19-c601-4740-9559-6db99ea782e9',
#   'annotation_uid': 'ebee2c27-b4e6-4ed2-a2ea-c2360d025cf0',
#   'query_idx': 1,
#   'clip_start_sec': 206.68845,
#   'clip_end_sec': 207.97,
#   'mIoU': 0.0,
#   'query': 'What did I take from the shelf hook '},
#  {'video_uid': 'b68709fe-2a73-49c3-a468-afcf56ab234c',
#   'clip_uid': '6e73e4ca-d147-40ea-8587-035e8f2850c7',
#   'annotation_uid': 'cc629689-4f0f-479f-a946-805808f3cf7d',
#   'query_idx': 9,
#   'clip_start_sec': 623.59334,
#   'clip_end_sec': 626.77386,
#   'mIoU': 0.0,
#   'query': 'What tool did I pick from the table?'},
#  {'video_uid': '182dffe9-d2bf-4a7d-b1d8-137470f0143d',
#   'clip_uid': 'cab983c1-d36e-4afa-8116-1e2bde4a4a4c',
#   'annotation_uid': '8bca6b25-cac7-4947-9cf0-2254113e8697',
#   'query_idx': 0,
#   'clip_start_sec': 17.51421,
#   'clip_end_sec': 20.666,
#   'mIoU': 0.0,
#   'query': 'Where was the chopping board before i picked it?'},
#  {'video_uid': '7d6d6cae-0601-485d-b900-482b4254e9f8',
#   'clip_uid': '5bff21b4-ac93-450f-a189-b2fb7cff4d99',
#   'annotation_uid': '1414e946-774f-4d94-99e3-8b72d2bfe930',
#   'query_idx': 7,
#   'clip_start_sec': 442.0,
#   'clip_end_sec': 475.0,
#   'mIoU': 0.0,
#   'query': 'Where was the hair brush?'},
#  {'video_uid': 'd526d862-080f-4b3e-9894-6ff997f5d6ac',
#   'clip_uid': 'b69e6150-0309-4202-bf4a-9a342f80d6d7',
#   'annotation_uid': 'b1d8a893-a87e-4b7a-8a1c-9b8f8fde9f41',
#   'query_idx': 1,
#   'clip_start_sec': 13.585,
#   'clip_end_sec': 13.585,
#   'mIoU': 0.0,
#   'query': 'what did  I  put in the  bucket?'},
#  {'video_uid': '45a02f60-e694-4bef-9c31-d5a71f556122',
#   'clip_uid': 'c6470548-81a3-4d9c-8bee-87a955948d5c',
#   'annotation_uid': '861763f7-591e-4f0e-8244-d91f2f7e0243',
#   'query_idx': 1,
#   'clip_start_sec': 6.87213,
#   'clip_end_sec': 11.872,
#   'mIoU': 0.0,
#   'query': 'where is the tent?'},
#  {'video_uid': 'c864505c-9d49-4da4-bf7e-254b4c348c03',
#   'clip_uid': '89f7ac43-956d-4d7e-b8a1-442ecff20ad6',
#   'annotation_uid': '68b2d5c2-8740-496b-8221-baedfde09087',
#   'query_idx': 6,
#   'clip_start_sec': 251.7102,
#   'clip_end_sec': 267.77468,
#   'mIoU': 0.0,
#   'query': 'What sachet did I fold?'},
#  {'video_uid': 'a4728450-c05c-4d51-91e4-348f571d74bc',
#   'clip_uid': '3231822a-fc8b-4207-b0b8-5cbb1344cb2f',
#   'annotation_uid': 'e664889e-c822-4646-afdc-4150fadde398',
#   'query_idx': 7,
#   'clip_start_sec': 316.42368,
#   'clip_end_sec': 337.82368,
#   'mIoU': 0.0,
#   'query': 'where did I place my hand while cooking?'},
#  {'video_uid': 'cd7c3bc6-24df-465c-9b63-a7961a7558de',
#   'clip_uid': 'c664f078-9b34-4a58-b949-180ac4bc0980',
#   'annotation_uid': '02755a4f-8f0c-46bf-a38f-780e3232752e',
#   'query_idx': 7,
#   'clip_start_sec': 156.67094,
#   'clip_end_sec': 158.64884,
#   'mIoU': 0.0,
#   'query': 'Where was the drilling machine before hitting the plank?\n'},
#  {'video_uid': '18a3840b-7463-43c4-9aa9-b1d8e486fa84',
#   'clip_uid': '4ecd1707-cce9-46bf-9846-11d031f79556',
#   'annotation_uid': '5f18498a-1243-4d03-a59e-cbe60c06e9ab',
#   'query_idx': 0,
#   'clip_start_sec': 30.0,
#   'clip_end_sec': 31.0,
#   'mIoU': 0.0,
#   'query': 'Where was the tape measure?'},
#  {'video_uid': 'cd7c3bc6-24df-465c-9b63-a7961a7558de',
#   'clip_uid': 'c664f078-9b34-4a58-b949-180ac4bc0980',
#   'annotation_uid': '02755a4f-8f0c-46bf-a38f-780e3232752e',
#   'query_idx': 6,
#   'clip_start_sec': 469.8856,
#   'clip_end_sec': 470.93117,
#   'mIoU': 0.0,
#   'query': 'In what location did I see the toolbox?'},
#  {'video_uid': '18a3840b-7463-43c4-9aa9-b1d8e486fa84',
#   'clip_uid': '8a855547-3574-4e67-a7ac-41b072984e3b',
#   'annotation_uid': '1918d43a-17fc-43d8-bfac-13bbd6dd3356',
#   'query_idx': 1,
#   'clip_start_sec': 38.92941,
#   'clip_end_sec': 44.49678,
#   'mIoU': 0.0,
#   'query': 'Where did I insert the blue wire?'},
#  {'video_uid': '30b9ff64-51c8-4481-ba6a-733ea2060aef',
#   'clip_uid': '1731de62-b1b9-4b84-bd55-412cd67e9b3c',
#   'annotation_uid': '058aa522-a4a2-4330-89c8-4d6091621de9',
#   'query_idx': 3,
#   'clip_start_sec': 62.33302,
#   'clip_end_sec': 69.128,
#   'mIoU': 0.0,
#   'query': 'Who did I talk to in the house?'},
#  {'video_uid': 'df0b81a6-826c-4e9b-8921-392304716c0e',
#   'clip_uid': 'eeca9b8b-d737-4a70-ad68-0cb49cf36a67',
#   'annotation_uid': '67307fe6-bb9a-48b4-a4f0-0c76ebc28f11',
#   'query_idx': 0,
#   'clip_start_sec': 0.0,
#   'clip_end_sec': 2.70572,
#   'mIoU': 0.0,
#   'query': 'What color is the tool box on the cabinet?'},
#  {'video_uid': '2ac65951-49b0-4629-981e-edc34b8cdb0f',
#   'clip_uid': '085f7a8b-e1e5-4e7b-a83d-5ea650edd9fe',
#   'annotation_uid': 'eacfb70a-8ac0-4ecc-a1da-a0030ec93ced',
#   'query_idx': 3,
#   'clip_start_sec': 8.20129,
#   'clip_end_sec': 11.13013,
#   'mIoU': 0.0,
#   'query': 'Where was the dog before I picked the leash?'},
#  {'video_uid': 'e636dd8b-7682-4910-8b26-781f192c37ec',
#   'clip_uid': '31e2ad5b-2566-4542-b18c-59febac66740',
#   'annotation_uid': '49000905-f450-46ea-9811-1f9d80ccec84',
#   'query_idx': 7,
#   'clip_start_sec': 151.60913,
#   'clip_end_sec': 155.428,
#   'mIoU': 0.0,
#   'query': 'Where were the cloths before I picked them?'},
#  {'video_uid': 'b884e44c-07d8-426e-8356-1be4905c2675',
#   'clip_uid': '6b9efa86-2580-465b-89b9-877dbd18467c',
#   'annotation_uid': '216012cf-8bde-4fb0-9314-5fc237199030',
#   'query_idx': 0,
#   'clip_start_sec': 5.34941,
#   'clip_end_sec': 7.0,
#   'mIoU': 0.0,
#   'query': 'What size was the black box?'},
#  {'video_uid': '2763dbfc-8488-4264-b31f-4b12096c4c4b',
#   'clip_uid': 'b1bd830a-a738-4ebe-9e88-c348def0de90',
#   'annotation_uid': '8d9613f4-caa1-4aec-8461-0eaeb31bc896',
#   'query_idx': 0,
#   'clip_start_sec': 27.12207,
#   'clip_end_sec': 28.41673,
#   'mIoU': 0.0,
#   'query': 'In what location did I see the empty orange keg?'},
#  {'video_uid': '363b5839-a7c3-4c2e-b966-9530e38045a1',
#   'clip_uid': '2b19ee03-d94f-4c1f-822d-d4c00a2066cc',
#   'annotation_uid': '6cbdae98-52c7-4551-9173-851d5e828812',
#   'query_idx': 5,
#   'clip_start_sec': 247.7484,
#   'clip_end_sec': 256.0,
#   'mIoU': 0.0,
#   'query': 'where is the toolbox?'},
#  {'video_uid': '7d6d6cae-0601-485d-b900-482b4254e9f8',
#   'clip_uid': '5bff21b4-ac93-450f-a189-b2fb7cff4d99',
#   'annotation_uid': '1414e946-774f-4d94-99e3-8b72d2bfe930',
#   'query_idx': 7,
#   'clip_start_sec': 442.0,
#   'clip_end_sec': 475.0,
#   'mIoU': 0.0,
#   'query': 'Where was the hair brush?'},
#  {'video_uid': '819257df-e650-4ed6-9c0b-26bd8e2ac726',
#   'clip_uid': '1bae2411-3eb4-4aa7-bdb5-c8634329d512',
#   'annotation_uid': 'bb51a1f5-be3c-4e42-be20-a667f53fde86',
#   'query_idx': 3,
#   'clip_start_sec': 402.62673,
#   'clip_end_sec': 405.0,
#   'mIoU': 0.0,
#   'query': 'Where was the knitted cape?'},
#  {'video_uid': 'c0f702e1-d2e3-4277-8981-7177d106174a',
#   'clip_uid': '8bf16989-e870-44bb-863c-c6745e69f6fb',
#   'annotation_uid': '2ccb1927-953d-422a-9765-cb7f6db4ca5c',
#   'query_idx': 5,
#   'clip_start_sec': 435.2079,
#   'clip_end_sec': 437.58563,
#   'mIoU': 0.0,
#   'query': 'What color of container did I pick from the ground?'},
#  {'video_uid': 'fec1f883-fc5c-4257-985e-26efaec68ddc',
#   'clip_uid': '53c86be4-190d-4410-8750-179a7edc70b3',
#   'annotation_uid': '6e530270-92ce-4518-b45a-94fe5aabf02f',
#   'query_idx': 4,
#   'clip_start_sec': 290.28542,
#   'clip_end_sec': 297.00418,
#   'mIoU': 0.0,
#   'query': 'How many dustbins were in the corridor?'},
#  {'video_uid': '824e7896-904a-4ff5-b7ee-e21df21918c2',
#   'clip_uid': 'e8842ef9-1d09-4393-ba98-ad18800c6f3e',
#   'annotation_uid': 'fd3c3693-1eef-4b96-bb4a-72361856b371',
#   'query_idx': 0,
#   'clip_start_sec': 187.28235,
#   'clip_end_sec': 190.87526,
#   'mIoU': 0.0,
#   'query': 'What color is the guitar?'},
#  {'video_uid': 'df0b81a6-826c-4e9b-8921-392304716c0e',
#   'clip_uid': 'eeca9b8b-d737-4a70-ad68-0cb49cf36a67',
#   'annotation_uid': '67307fe6-bb9a-48b4-a4f0-0c76ebc28f11',
#   'query_idx': 6,
#   'clip_start_sec': 207.41635,
#   'clip_end_sec': 210.037,
#   'mIoU': 0.0,
#   'query': 'Where is the power tool?'},
#  {'video_uid': 'adf65602-f5ee-456a-a098-db19a521ce38',
#   'clip_uid': 'a185abe1-ae2e-4ab4-aa5c-d2f45abfd7c9',
#   'annotation_uid': '043c0c21-82d5-4f6d-8971-4aff968143ee',
#   'query_idx': 1,
#   'clip_start_sec': 89.34805,
#   'clip_end_sec': 89.34805,
#   'mIoU': 0.0,
#   'query': 'what color is the towel'},
#  {'video_uid': '9f28e782-417c-4c8b-a7ae-42fc96a0e94f',
#   'clip_uid': 'd7b8f461-db42-4365-9f89-83f923528293',
#   'annotation_uid': 'fa5f4111-651a-495e-b006-d5be045b4091',
#   'query_idx': 7,
#   'clip_start_sec': 446.42212,
#   'clip_end_sec': 467.30328,
#   'mIoU': 0.0,
#   'query': 'How many tomatoes did I chop?'},
#  {'video_uid': '18a3840b-7463-43c4-9aa9-b1d8e486fa84',
#   'clip_uid': '8a855547-3574-4e67-a7ac-41b072984e3b',
#   'annotation_uid': 'ba9a6987-2517-47b3-8928-fecb9d538dc4',
#   'query_idx': 5,
#   'clip_start_sec': 214.94763,
#   'clip_end_sec': 218.947,
#   'mIoU': 0.0,
#   'query': 'Where did I put the ceiling cornice?'},
#  {'video_uid': '115774b6-534d-444f-b7aa-d1b834eb0ee7',
#   'clip_uid': 'f748feb9-9a15-4f2b-9b65-186f90107c7c',
#   'annotation_uid': 'ed904e38-6e0e-4e4e-9bfe-d4b28127fde4',
#   'query_idx': 11,
#   'clip_start_sec': 1094.50172,
#   'clip_end_sec': 1095.45814,
#   'mIoU': 0.0,
#   'query': 'In what room did i see the broom ?'},
#  {'video_uid': '2d29b45a-169b-453f-8050-98ec147b0ccf',
#   'clip_uid': 'a769264b-e62e-4515-be98-a5828a533e45',
#   'annotation_uid': '981741ad-4934-43a6-8517-29766b4b5049',
#   'query_idx': 1,
#   'clip_start_sec': 21.39145,
#   'clip_end_sec': 22.097,
#   'mIoU': 0.0,
#   'query': 'Where were the hammer before I picked it up?'},
#  {'video_uid': '516c9abc-dbf3-4f87-b78e-db0ab9d657ea',
#   'clip_uid': '86c3b190-a57a-4b88-a3be-4d8d47c8d867',
#   'annotation_uid': 'ccd6ec61-d38f-47b2-aae8-95e1f96de032',
#   'query_idx': 4,
#   'clip_start_sec': 202.83455,
#   'clip_end_sec': 207.32256,
#   'mIoU': 0.0,
#   'query': 'What color is the rag that I washed?'},
#  {'video_uid': '603ecf93-d2c1-4611-a690-76afd18935c8',
#   'clip_uid': 'cf1470f1-9a03-4944-95dd-7f8410bb6cc8',
#   'annotation_uid': '5466f293-f137-4272-806f-61ad284eb5f9',
#   'query_idx': 17,
#   'clip_start_sec': 945.37875,
#   'clip_end_sec': 947.72783,
#   'mIoU': 0.0,
#   'query': 'In what area did I leave the basin?'},
#  {'video_uid': '3ee7070a-fe81-49a9-97a2-902268af9985',
#   'clip_uid': 'a40dce18-488d-4acc-b754-fcd56c204db1',
#   'annotation_uid': '69ff5b62-0df3-4a8f-aa16-e224d4aa549e',
#   'query_idx': 0,
#   'clip_start_sec': 317.0,
#   'clip_end_sec': 341.0,
#   'mIoU': 0.0,
#   'query': 'Where did I put the remaining onions?'},
#  {'video_uid': 'd61475bb-fd97-43e3-8b7d-a242064a9d10',
#   'clip_uid': '534d9bf8-bdc5-4236-8dba-dd7b894218d2',
#   'annotation_uid': '9dafc673-3cd8-453d-ade5-b86cbf0a9df4',
#   'query_idx': 3,
#   'clip_start_sec': 397.85133,
#   'clip_end_sec': 398.95691,
#   'mIoU': 0.0,
#   'query': 'What card did I pick?'},
#  {'video_uid': 'f324ccbc-bef5-4d68-9722-cc99bdaaa660',
#   'clip_uid': '5e59031d-0deb-4557-a3e1-ba0ba2bb5465',
#   'annotation_uid': '5f858205-4a3d-46c8-b2e3-391e7a958987',
#   'query_idx': 9,
#   'clip_start_sec': 232.97875,
#   'clip_end_sec': 236.50409,
#   'mIoU': 0.0,
#   'query': 'Where were the napkins I folded?'},
#  {'video_uid': 'fec1f883-fc5c-4257-985e-26efaec68ddc',
#   'clip_uid': '53c86be4-190d-4410-8750-179a7edc70b3',
#   'annotation_uid': '6e530270-92ce-4518-b45a-94fe5aabf02f',
#   'query_idx': 16,
#   'clip_start_sec': 1167.52658,
#   'clip_end_sec': 1173.61713,
#   'mIoU': 0.0,
#   'query': 'In what location did I see the television?'},
#  {'video_uid': '4d89d233-dbcf-4ea2-a90f-9a2c3b42d1d5',
#   'clip_uid': 'feaf7655-ad23-4150-9e9d-552c369db96d',
#   'annotation_uid': '090121f8-b755-49b0-bba2-a9eebf45c67c',
#   'query_idx': 3,
#   'clip_start_sec': 214.63553,
#   'clip_end_sec': 230.14267,
#   'mIoU': 0.0,
#   'query': 'What wooden plank did I cut into two with the sawing machine in the garage?'},
#  {'video_uid': '8d84ee2b-5dcb-4311-9769-a52e7b68d9e1',
#   'clip_uid': 'b9cd86ff-d01f-4faa-9d2b-c53799e47273',
#   'annotation_uid': '2b1babcf-3862-4a47-94cd-17db37987d44',
#   'query_idx': 5,
#   'clip_start_sec': 361.64149,
#   'clip_end_sec': 369.8375,
#   'mIoU': 0.0,
#   'query': 'What tool did I pick up from the ground?'},
#  {'video_uid': '85775377-b334-4bd7-8cfc-16885099cc9a',
#   'clip_uid': '35cd9ace-642f-4550-8e63-a5c2caae89ed',
#   'annotation_uid': 'c1a0d621-e201-4731-9510-dfb75ffdac92',
#   'query_idx': 0,
#   'clip_start_sec': 158.42089,
#   'clip_end_sec': 164.76382,
#   'mIoU': 0.0,
#   'query': 'Where was the car after I switched on the lights'}]

# %%
import pandas as pd

# %%
pd.DataFrame(mIoUs).iloc[:17].to_excel('juli_mIoU_results.xlsx')

# %%
annotations_uid = '''efa2bedf-3eb9-43c3-9581-da4a64922820
450c2f2b-5172-4d6f-91fa-495c7f1fb986
0a2b574a-983d-4ef3-9f53-3a1c439eaa90
bf881c93-b0b7-40fc-8876-6ea5a37285f1
e1c56ec0-9d21-4319-bb33-a774545bdd9e
364fcd89-9a8e-4208-aa75-8649f37d8534
91c2e888-87a8-4611-af64-41daaf4b4cbd
55bc7494-95ef-4e47-87db-9529b298c1ef
450c2f2b-5172-4d6f-91fa-495c7f1fb986
a657d6dc-c63c-436a-9a68-ece04c4b4e99
efa7da94-3c84-48d3-a8cf-d9bc0ba377da
7bc5d786-fc59-49ad-8a0e-5e3f19e21456
e93f1e16-136d-4e25-8b89-1fa3d6c2b74e
9a7530dc-6af4-4e87-973a-8112169bb643
260cbcea-d2a7-4c11-b944-4ed391a57606
9a089219-ef96-45fa-be4b-21ca0575bd1c
ec428ae0-93c2-4326-bb41-5c1ea12056fd
260cbcea-d2a7-4c11-b944-4ed391a57606
38910a69-1952-485c-8763-7018951c1d5d
8d6624bd-a645-47e1-b729-a468ce3a4d64
1a039f8c-10c1-4740-8fb4-f4e9120d533e
70233dd6-95d2-4b5a-93ec-0212819ca311
0d83a02d-0ed0-439a-98b6-5b9d479f8880
2b090649-95f0-4e45-ac75-42d944582858
fd433c90-cae2-4bd7-ad2d-980e372995e8
1ce5b1fc-63d9-4af2-9cb7-8de53f8bbf16
ccb33087-cfbe-47ba-9a13-3727880ed1fb
29211699-a701-49f7-8936-18fc8fa5fcf9
e0c0f9ff-3269-4d7f-8ccb-9148867166d1
82916af0-57da-4ea2-86ca-19a8d5ffd858
a6cd5d8f-1de0-4c51-bc5a-1d2c2d7fb086
8bca6b25-cac7-4947-9cf0-2254113e8697
f35a2b55-622a-433e-a218-90769e474831
f97483e6-04c9-441a-9487-67348e976999
efa2bedf-3eb9-43c3-9581-da4a64922820
b276bc56-afeb-4bc8-8855-73827e597ee3
38354dcf-ba90-47aa-a75e-807ba6bb43fb
7d065fba-8547-46e9-b968-97b02db4a656
d2ba7cbc-d85e-43e2-8078-193aa9e99c24
f8632640-58bf-4a4b-89be-3c8ed0cb07f8
acfc079e-7165-4508-8694-faddb6aacfc9
ed904e38-6e0e-4e4e-9bfe-d4b28127fde4
8037e8a7-1a43-426b-ae49-1ab829373b28
d8c3d311-7798-4d65-87ae-b6eb3385e2cc
00b912ca-3192-4312-b901-6720fce0a3d0
49c661cc-3a02-42d2-b8cb-1341cf0fd7ac
0139f386-6dc6-4aad-a150-dc6745338445
7f82729b-db06-4e3e-8a4f-2e345a7366b6
043c0c21-82d5-4f6d-8971-4aff968143ee
a89efc9c-f6bb-472a-a8c6-bdae52f82638'''

# %%
annotations_uid = annotations_uid.split('\n')

# %%
len(set(annotations_uid))
# Out:
# 47

# %%
for id in annotations_uid:
    if annotations_uid.count(id) > 1:
        print(id)
